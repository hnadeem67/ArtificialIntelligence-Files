# %%
#from google.colab import drive
#drive.mount('/content/drive/AI/final_project_cvs')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


#df = pd.concat(map(pd.read_csv, ['d1.csv', 'd2.csv','d3.csv']))
df1 = pd.read_csv('NYPD_Complaint_Data_Historic.csv')
df1 = df1.dropna()
df2 = pd.read_csv('Crime_Column_Description.csv')
df3 = pd.read_csv('Crime_Column_Description.csv')

print(df1.columns)
print(df2.columns)
print(df3.columns)
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (17) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Index(['CMPLNT_NUM', 'CMPLNT_FR_DT', 'CMPLNT_FR_TM', 'CMPLNT_TO_DT',
#        'CMPLNT_TO_TM', 'RPT_DT', 'KY_CD', 'OFNS_DESC', 'PD_CD', 'PD_DESC',
#        'CRM_ATPT_CPTD_CD', 'LAW_CAT_CD', 'JURIS_DESC', 'BORO_NM',
#        'ADDR_PCT_CD', 'LOC_OF_OCCUR_DESC', 'PREM_TYP_DESC', 'PARKS_NM',
#        'HADEVELOPT', 'X_COORD_CD', 'Y_COORD_CD', 'Latitude', 'Longitude',
#        'Lat_Lon'],
#       dtype='object')
# Index(['Column', 'Description'], dtype='object')
# Index(['Column', 'Description'], dtype='object')

# %%
df1.head(5)
# Out:
#        CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM  \
# 12104   479888864   12/21/2015      9:31:00   12/21/2015      9:47:00
# 15600   817223136   12/18/2015     15:30:00   12/18/2015     15:35:00
# 16575   144702604   12/17/2015     22:30:00   12/17/2015     22:56:00
# 28742   426614014    12/8/2015     20:50:00    12/8/2015     20:58:00
# 43263   598084040   11/27/2015     11:25:00   11/27/2015     11:30:00
#
#            RPT_DT  KY_CD                OFNS_DESC  PD_CD  \
# 12104  12/21/2015    106           FELONY ASSAULT  106.0
# 15600  12/18/2015    105                  ROBBERY  386.0
# 16575  12/17/2015    126  MISCELLANEOUS PENAL LAW  760.0
# 28742   12/8/2015    236        DANGEROUS WEAPONS  782.0
# 43263  11/27/2015    235          DANGEROUS DRUGS  567.0
#
#                                   PD_DESC  ... ADDR_PCT_CD LOC_OF_OCCUR_DESC  \
# 12104           ASSAULT 2,1,PEACE OFFICER  ...        76.0           REAR OF
# ...

# %%
df1.tail(5)
# Out:
#         CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM  \
# 704541   260543857    7/17/2014     18:30:00    7/17/2014     18:30:00
# 709635   487186695    7/13/2014     20:30:00    7/13/2014     20:45:00
# 713615   330740886    7/11/2014      1:10:00    7/11/2014      1:21:00
# 715850   919428487     7/9/2014     21:15:00     7/9/2014     21:26:00
# 717414   213481643     7/8/2014     20:50:00     7/8/2014     21:10:00
#
#            RPT_DT  KY_CD                       OFNS_DESC  PD_CD  \
# 704541  7/17/2014    359  OFFENSES AGAINST PUBLIC ADMINI  750.0
# 709635  7/14/2014    109                   GRAND LARCENY  439.0
# 713615  7/11/2014    118               DANGEROUS WEAPONS  793.0
# 715850   7/9/2014    352               CRIMINAL TRESPASS  203.0
# 717414   7/8/2014    236               DANGEROUS WEAPONS  782.0
#
#                                           PD_DESC  ... ADDR_PCT_CD  \
# 704541                           RESISTING ARREST  ...        79.0
# ...

# %%
df1.info()
df2.info()
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 115 entries, 12104 to 717414
# Data columns (total 24 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CMPLNT_NUM         115 non-null    int64
#  1   CMPLNT_FR_DT       115 non-null    object
#  2   CMPLNT_FR_TM       115 non-null    object
#  3   CMPLNT_TO_DT       115 non-null    object
#  4   CMPLNT_TO_TM       115 non-null    object
#  5   RPT_DT             115 non-null    object
#  6   KY_CD              115 non-null    int64
#  7   OFNS_DESC          115 non-null    object
#  8   PD_CD              115 non-null    float64
#  9   PD_DESC            115 non-null    object
#  10  CRM_ATPT_CPTD_CD   115 non-null    object
#  11  LAW_CAT_CD         115 non-null    object
#  12  JURIS_DESC         115 non-null    object
#  13  BORO_NM            115 non-null    object
#  14  ADDR_PCT_CD        115 non-null    float64
#  15  LOC_OF_OCCUR_DESC  115 non-null    object
# ...

# %%
#df2.head(5) 
#df2.tail(5)

# %%
df1.isnull().sum()
# Out:
# CMPLNT_NUM           0
# CMPLNT_FR_DT         0
# CMPLNT_FR_TM         0
# CMPLNT_TO_DT         0
# CMPLNT_TO_TM         0
# RPT_DT               0
# KY_CD                0
# OFNS_DESC            0
# PD_CD                0
# PD_DESC              0
# CRM_ATPT_CPTD_CD     0
# LAW_CAT_CD           0
# JURIS_DESC           0
# BORO_NM              0
# ADDR_PCT_CD          0
# LOC_OF_OCCUR_DESC    0
# PREM_TYP_DESC        0
# PARKS_NM             0
# HADEVELOPT           0
# X_COORD_CD           0
# Y_COORD_CD           0
# Latitude             0
# Longitude            0
# Lat_Lon              0
# dtype: int64

# %%
df3.isnull().sum()
# Out:
# Column         0
# Description    0
# dtype: int64

# %%
df1.describe()
# Out:
#          CMPLNT_NUM       KY_CD       PD_CD  ADDR_PCT_CD    X_COORD_CD  \
# count  1.150000e+02  115.000000  115.000000   115.000000  1.150000e+02
# mean   5.462392e+08  267.391304  506.852174    57.852174  1.002461e+06
# std    2.556921e+08  133.510345  224.520317    28.684687  1.500056e+04
# min    1.305885e+08  105.000000  101.000000     5.000000  9.388760e+05
# 25%    3.366440e+08  126.000000  362.500000    40.000000  9.936265e+05
# 50%    5.278540e+08  235.000000  567.000000    60.000000  1.001769e+06
# 75%    7.818436e+08  344.000000  707.000000    76.000000  1.011550e+06
# max    9.945151e+08  677.000000  899.000000   122.000000  1.030347e+06
#
#         Y_COORD_CD    Latitude   Longitude
# count     115.0000  115.000000  115.000000
# mean   209689.4000   40.742202  -73.934254
# std     29561.7832    0.081133    0.054135
# min    155544.0000   40.593616  -74.163474
# 25%    184392.0000   40.672781  -73.966136
# 50%    200467.0000   40.716918  -73.936715
# ...

# %%
for col in df1.columns:
    print('{} : {}'.format(col,df1[col].unique()))
# Out:
# CMPLNT_NUM : [479888864 817223136 144702604 426614014 598084040 210529961 411947704
#  212734256 960692666 548537850 614423009 657671149 163926775 360101275
#  496575465 153977824 598747226 961765663 867053472 760535260 168869016
#  191190938 857488993 392899762 956081465 797546064 196375030 361104967
#  955916551 527853996 203411417 231533895 342547056 514034585 939576404
#  378348074 396825596 577516182 802147164 459691980 897278833 451716308
#  303595288 196727559 651563138 343526176 239081229 785657494 600949177
#  278541901 208750731 371433524 437581838 699428500 931007081 236708722
#  436242235 882593795 577944076 911433034 717308455 797240007 803604608
#  297023367 622820921 636493763 692153852 988556553 557334123 539264273
#  743838912 385554924 317242485 990462021 612420483 417516127 817299529
#  209170858 304512712 901147675 726980574 268513761 387851425 846822521
#  369931306 438426820 925864471 573485959 407878081 778029794 323021092
# ...

# %%
# Print unique values in a certian column
print(df1['LAW_CAT_CD'].unique())

# We have three categories
# Out:
# ['FELONY' 'MISDEMEANOR' 'VIOLATION']

# %%
print(df1.columns)
# Out:
# Index(['CMPLNT_NUM', 'CMPLNT_FR_DT', 'CMPLNT_FR_TM', 'CMPLNT_TO_DT',
#        'CMPLNT_TO_TM', 'RPT_DT', 'KY_CD', 'OFNS_DESC', 'PD_CD', 'PD_DESC',
#        'CRM_ATPT_CPTD_CD', 'LAW_CAT_CD', 'JURIS_DESC', 'BORO_NM',
#        'ADDR_PCT_CD', 'LOC_OF_OCCUR_DESC', 'PREM_TYP_DESC', 'PARKS_NM',
#        'HADEVELOPT', 'X_COORD_CD', 'Y_COORD_CD', 'Latitude', 'Longitude',
#        'Lat_Lon'],
#       dtype='object')

# %%
#print(df1.nunique())

# count unique values from each 
#print(df1['LAW_CAT_CD'].value_counts())


counts = df1['LAW_CAT_CD'].value_counts()
print(counts)
# Out:
# MISDEMEANOR    75
# FELONY         31
# VIOLATION       9
# Name: LAW_CAT_CD, dtype: int64

# %%
#Plotting Data from a specific column into a piechart

data = pd.DataFrame({'Number of ':[counts[0],counts[1],counts[2]]},index=['MISDEMEANOR','FELONY','VIOLATION'])

plot = data.plot.pie(y='Number of ',figsize = (5,5))

# %%
burr = df1['BORO_NM'].value_counts()
print(burr)
# Out:
# BROOKLYN         50
# BRONX            28
# MANHATTAN        28
# QUEENS            6
# STATEN ISLAND     3
# Name: BORO_NM, dtype: int64

# %%
dataBURR = pd.DataFrame({'Number of crimes per Boroughs':[burr[0],burr[1],burr[2],burr[3],burr[4]]},index=['BROOKLYN','MANHATTAN','BRONX','QUEENS','STATEN ISLAND'])

plot = dataBURR.plot.pie(y='Number of crimes per Boroughs',figsize = (8,8))

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 115 entries, 12104 to 717414
# Data columns (total 24 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CMPLNT_NUM         115 non-null    int64
#  1   CMPLNT_FR_DT       115 non-null    object
#  2   CMPLNT_FR_TM       115 non-null    object
#  3   CMPLNT_TO_DT       115 non-null    object
#  4   CMPLNT_TO_TM       115 non-null    object
#  5   RPT_DT             115 non-null    object
#  6   KY_CD              115 non-null    int64
#  7   OFNS_DESC          115 non-null    object
#  8   PD_CD              115 non-null    float64
#  9   PD_DESC            115 non-null    object
#  10  CRM_ATPT_CPTD_CD   115 non-null    object
#  11  LAW_CAT_CD         115 non-null    object
#  12  JURIS_DESC         115 non-null    object
#  13  BORO_NM            115 non-null    object
#  14  ADDR_PCT_CD        115 non-null    float64
#  15  LOC_OF_OCCUR_DESC  115 non-null    object
# ...

# %%
sns.histplot(data=df1, x=df1['LAW_CAT_CD'],color='red')

# %%
sns.histplot(data=df1, x=df1['BORO_NM'],color='blue')

# %% [markdown]
# HYPOTHESIS: Segregate Burrows based on type of crime.

# %%
#print(df1.sort_values(by=['LAW_CAT_CD'=='FELONY']))

# %%
df1['FELONY'] = pd.Categorical(df1['LAW_CAT_CD'],categories=['FELONY'])
df1['FELONY']
# Out:
# 12104     FELONY
# 15600     FELONY
# 16575     FELONY
# 28742        NaN
# 43263        NaN
#            ...
# 704541       NaN
# 709635    FELONY
# 713615    FELONY
# 715850       NaN
# 717414       NaN
# Name: FELONY, Length: 115, dtype: category
# Categories (1, object): ['FELONY']

# %%
# MISDEMEANOR in different burrows ('BRONX', 'QUEENS', 'MANHATTAN',
#                                     'STATEN ISLAND','BROOKLYN')

df1['Mis'] = pd.Categorical(df1['LAW_CAT_CD'],categories=['MISDEMEANOR'])
lengthMis = len(df1['Mis']) - df1['Mis'].isnull().sum()
print(lengthMis)
# Brooklyn
df1['MisBrooklyn'] = pd.Categorical(df1['BORO_NM'],categories=['BROOKLYN'])
lengthMisBrook = len(df1['MisBrooklyn']) - df1['MisBrooklyn'].isnull().sum()
print('Number of Misdemnors in Brooklyn',lengthMisBrook)
#Bronx
df1['MisBronx'] = pd.Categorical(df1['BORO_NM'],categories=['BRONX'])
lengthMisBronx = len(df1['MisBronx']) - df1['MisBronx'].isnull().sum()
print('Number of Misdemnors in Bronx',lengthMisBronx)
# QUEENS
df1['MisQueens'] = pd.Categorical(df1['BORO_NM'],categories=['QUEENS'])
lengthMisQueens = len(df1['MisQueens']) - df1['MisQueens'].isnull().sum()
print('Number of Misdemnors in Queens',lengthMisQueens)
#MANHATTAN
df1['MisMan'] = pd.Categorical(df1['BORO_NM'],categories=['MANHATTAN'])
lengthMisMan = len(df1['MisMan']) - df1['MisMan'].isnull().sum()
print('Number of Misdemnors in Manhattan',lengthMisMan)
#STATEN ISLAND
df1['MisSI'] = pd.Categorical(df1['BORO_NM'],categories=['STATEN ISLAND'])
lengthMisSI = len(df1['MisSI']) - df1['MisSI'].isnull().sum()
print('Number of Misdemnors in Staten ISland',lengthMisSI)
# Out:
# 75
# Number of Misdemnors in Brooklyn 50
# Number of Misdemnors in Bronx 28
# Number of Misdemnors in Queens 6
# Number of Misdemnors in Manhattan 28
# Number of Misdemnors in Staten ISland 3

# %%
# burrowListFelony = []
# burrowListMis = []
# burrowListVio =[]
# for i in range(0, int(len(df1['LAW_CAT_CD'])/4)):
# #for i in range(0,1048575):
#   #print(df1['LAW_CAT_CD'].iloc[i])
#   #print(len(df1['LAW_CAT_CD']))
#   if df1['LAW_CAT_CD'].iloc[i] == 'MISDEMEANOR':
#     burrowListMis.append(df1['BORO_NM'].iloc[i])
#   elif df1['LAW_CAT_CD'].iloc[i] == 'FELONY':
#      burrowListFelony.append(df1['BORO_NM'].iloc[i])
#   else:
#     burrowListVio.append(df1['BORO_NM'].iloc[i])

# print("Print Felony:\n",burrowListFelony)
# print("Print MIS:\n",burrowListMis)
# print("Print VIO:\n",burrowListVio)

# #df1['FelonyBurrow'] = burrowListFelony
