# %%
from google.colab import drive
drive.mount('/content/gdrive');
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df1 = pd.read_csv('/content/gdrive/MyDrive/AI/final_project_csvs/NYPD_Complaint_Data_Historic.csv')
#df1 = df1.fillna(1)
df2 = pd.read_csv('/content/gdrive/MyDrive/AI/final_project_csvs/Crime_Column_Description.csv')
df3 = pd.read_csv('/content/gdrive/MyDrive/AI/final_project_csvs/Population_by_Borough_NYC.csv')

# #df = pd.concat(map(pd.read_csv, ['d1.csv', 'd2.csv','d3.csv']))
# df1 = pd.read_csv('NYPD_Complaint_Data_Historic.csv')
# #df1 = df1.dropna()
# df2 = pd.read_csv('Crime_Column_Description.csv')
# df3 = pd.read_csv('Population_by_Borough_NYC.csv')

#X ={df1,df2}
print('Lenght of DF1 is:',len(df1))
print(df1.columns)
print(df2.columns)
print(df3.columns)
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (17) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Lenght of DF1 is: 1048575
# Index(['CMPLNT_NUM', 'CMPLNT_FR_DT', 'CMPLNT_FR_TM', 'CMPLNT_TO_DT',
#        'CMPLNT_TO_TM', 'RPT_DT', 'KY_CD', 'OFNS_DESC', 'PD_CD', 'PD_DESC',
#        'CRM_ATPT_CPTD_CD', 'LAW_CAT_CD', 'JURIS_DESC', 'BORO_NM',
#        'ADDR_PCT_CD', 'LOC_OF_OCCUR_DESC', 'PREM_TYP_DESC', 'PARKS_NM',
#        'HADEVELOPT', 'X_COORD_CD', 'Y_COORD_CD', 'Latitude', 'Longitude',
#        'Lat_Lon'],
#       dtype='object')
# Index(['Column', 'Description'], dtype='object')
# Index(['Age Group', 'Borough', '1950', '1950 - Boro share of NYC total',
#        '1960', '1960 - Boro share of NYC total', '1970',
#        '1970 - Boro share of NYC total', '1980',
#        '1980 - Boro share of NYC total', '1990',
#        '1990 - Boro share of NYC total', '2000',
#        '2000 - Boro share of NYC total', '2010',
#        '2010 - Boro share of NYC total', '2020',
#        '2020 - Boro share of NYC total', '2030',
#        '2030 - Boro share of NYC total', '2040',
#        '2040 - Boro share of NYC total'],
#       dtype='object')

# %%
# sample for the test run and comment out for the full run
df1 = df1.sample(500000)

# %%
df1.columns
# Out:
# Index(['CMPLNT_NUM', 'CMPLNT_FR_DT', 'CMPLNT_FR_TM', 'CMPLNT_TO_DT',
#        'CMPLNT_TO_TM', 'RPT_DT', 'KY_CD', 'OFNS_DESC', 'PD_CD', 'PD_DESC',
#        'CRM_ATPT_CPTD_CD', 'LAW_CAT_CD', 'JURIS_DESC', 'BORO_NM',
#        'ADDR_PCT_CD', 'LOC_OF_OCCUR_DESC', 'PREM_TYP_DESC', 'PARKS_NM',
#        'HADEVELOPT', 'X_COORD_CD', 'Y_COORD_CD', 'Latitude', 'Longitude',
#        'Lat_Lon', 'Food & beverage', 'Food and beverage',
#        'RESIDENCEBooleanValues', 'FELONY', 'Vio'],
#       dtype='object')

# %%
df1[['ADDR_PCT_CD','BORO_NM']]
# Out:
#         ADDR_PCT_CD    BORO_NM
# 46300          78.0   BROOKLYN
# 571249         84.0   BROOKLYN
# 585411        106.0     QUEENS
# 834377         19.0  MANHATTAN
# 768712        115.0     QUEENS
# ...             ...        ...
# 993387         13.0  MANHATTAN
# 326471         23.0  MANHATTAN
# 601408         69.0   BROOKLYN
# 957908         20.0  MANHATTAN
# 487216         43.0      BRONX
#
# [500000 rows x 2 columns]

# %%
df2
# Out:
#                Column                                        Description
# 0          CMPLNT_NUM  Randomly generated persistent ID for each comp...
# 1        CMPLNT_FR_DT  Exact date of occurrence for the reported even...
# 2        CMPLNT_FR_TM  Exact time of occurrence for the reported even...
# 3        CMPLNT_TO_DT  Ending date of occurrence for the reported eve...
# 4        CMPLNT_TO_TM  Ending time of occurrence for the reported eve...
# 5              RPT_DT                 Date event was reported to police
# 6               KY_CD            Three digit offense classification code
# 7           OFNS_DESC  Description of offense corresponding with key ...
# 8               PD_CD  Three digit internal classification code (more...
# 9             PD_DESC  Description of internal classification corresp...
# 10   CRM_ATPT_CPTD_CD  Indicator of whether crime was successfully co...
# 11         LAW_CAT_CD  Level of offense: felony, misdemeanor, violation
# 12         JURIS_DESC  Jurisdiction responsible for incident. Either ...
# 13            BORO_NM  The name of the borough in which the incident ...
# 14        ADDR_PCT_CD        The precinct in which the incident occurred
# 15  LOC_OF_OCCUR_DESC  Specific location of occurrence in or around t...
# 16      PREM_TYP_DESC  Specific description of premises; grocery stor...
# 17           PARKS_NM  Name of NYC park, playground or greenspace of ...
# 18         HADEVELOPT  Name of NYCHA housing development of occurrenc...
# 19         X_COORD_CD  X-coordinate for New York State Plane Coordina...
# 20         Y_COORD_CD  Y-coordinate for New York State Plane Coordina...
# 21           Latitude  Latitude coordinate for Global Coordinate Syst...
# 22          Longitude  Longitude coordinate for Global Coordinate Sys...

# %%
df1.info()
df2.info()
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500000 entries, 46300 to 487216
# Data columns (total 24 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   CMPLNT_NUM         500000 non-null  int64
#  1   CMPLNT_FR_DT       499978 non-null  object
#  2   CMPLNT_FR_TM       500000 non-null  object
#  3   CMPLNT_TO_DT       402043 non-null  object
#  4   CMPLNT_TO_TM       402198 non-null  object
#  5   RPT_DT             500000 non-null  object
#  6   KY_CD              500000 non-null  int64
#  7   OFNS_DESC          498620 non-null  object
#  8   PD_CD              499658 non-null  float64
#  9   PD_DESC            499658 non-null  object
#  10  CRM_ATPT_CPTD_CD   499999 non-null  object
#  11  LAW_CAT_CD         500000 non-null  object
#  12  JURIS_DESC         500000 non-null  object
#  13  BORO_NM            500000 non-null  object
#  14  ADDR_PCT_CD        499999 non-null  float64
#  15  LOC_OF_OCCUR_DESC  396289 non-null  object
#  16  PREM_TYP_DESC      497766 non-null  object
#  17  PARKS_NM           3655 non-null    object
#  18  HADEVELOPT         24809 non-null   object
#  19  X_COORD_CD         484702 non-null  float64
#  20  Y_COORD_CD         484702 non-null  float64
#  21  Latitude           484702 non-null  float64
#  22  Longitude          484702 non-null  float64
#  23  Lat_Lon            484702 non-null  object
# dtypes: float64(6), int64(2), object(16)
# memory usage: 95.4+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Column       23 non-null     object
#  1   Description  23 non-null     object
# dtypes: object(2)
# memory usage: 496.0+ bytes
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 22 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Age Group                       6 non-null      object
#  1   Borough                         6 non-null      object
#  2   1950                            6 non-null      object
#  3   1950 - Boro share of NYC total  6 non-null      object
#  4   1960                            6 non-null      object
#  5   1960 - Boro share of NYC total  6 non-null      object
#  6   1970                            6 non-null      object
#  7   1970 - Boro share of NYC total  6 non-null      object
#  8   1980                            6 non-null      object
#  9   1980 - Boro share of NYC total  6 non-null      object
#  10  1990                            6 non-null      object
#  11  1990 - Boro share of NYC total  6 non-null      object
#  12  2000                            6 non-null      object
#  13  2000 - Boro share of NYC total  6 non-null      object
#  14  2010                            6 non-null      object
#  15  2010 - Boro share of NYC total  6 non-null      object
#  16  2020                            6 non-null      object
#  17  2020 - Boro share of NYC total  6 non-null      object
#  18  2030                            6 non-null      object
#  19  2030 - Boro share of NYC total  6 non-null      object
#  20  2040                            6 non-null      object
#  21  2040 - Boro share of NYC total  6 non-null      object
# dtypes: object(22)
# memory usage: 1.2+ KB

# %%
df1.isnull().sum()
# Out:
# CMPLNT_NUM                0
# CMPLNT_FR_DT             22
# CMPLNT_FR_TM              0
# CMPLNT_TO_DT          97957
# CMPLNT_TO_TM          97802
# RPT_DT                    0
# KY_CD                     0
# OFNS_DESC              1380
# PD_CD                   342
# PD_DESC                 342
# CRM_ATPT_CPTD_CD          1
# LAW_CAT_CD                0
# JURIS_DESC                0
# BORO_NM                   0
# ADDR_PCT_CD               1
# LOC_OF_OCCUR_DESC    103711
# PREM_TYP_DESC          2234
# PARKS_NM             496345
# HADEVELOPT           475191
# X_COORD_CD            15298
# Y_COORD_CD            15298
# Latitude              15298
# Longitude             15298
# Lat_Lon               15298
# dtype: int64

# %%
df3.isnull().sum()
# Out:
# Age Group                         0
# Borough                           0
# 1950                              0
# 1950 - Boro share of NYC total    0
# 1960                              0
# 1960 - Boro share of NYC total    0
# 1970                              0
# 1970 - Boro share of NYC total    0
# 1980                              0
# 1980 - Boro share of NYC total    0
# 1990                              0
# 1990 - Boro share of NYC total    0
# 2000                              0
# 2000 - Boro share of NYC total    0
# 2010                              0
# 2010 - Boro share of NYC total    0
# 2020                              0
# 2020 - Boro share of NYC total    0
# 2030                              0
# 2030 - Boro share of NYC total    0
# 2040                              0
# 2040 - Boro share of NYC total    0
# dtype: int64

# %%
df1.describe()
# Out:
#          CMPLNT_NUM          KY_CD          PD_CD    ADDR_PCT_CD  \
# count  5.000000e+05  500000.000000  499658.000000  499999.000000
# mean   5.496784e+08     295.456666     409.677325      63.814404
# std    2.599315e+08     150.645116     219.174480      34.344601
# min    1.000036e+08     101.000000     101.000000       1.000000
# 25%    3.243697e+08     117.000000     254.000000      40.000000
# 50%    5.491420e+08     341.000000     357.000000      66.000000
# 75%    7.748134e+08     351.000000     637.000000      94.000000
# max    9.999948e+08     881.000000     975.000000     123.000000
#
#          X_COORD_CD     Y_COORD_CD       Latitude      Longitude
# count  4.847020e+05  484702.000000  484702.000000  484702.000000
# mean   1.004974e+06  206790.693049      40.734227     -73.925193
# std    2.148395e+04   30442.914818       0.083562       0.077478
# min    9.133190e+05  121152.000000      40.498957     -74.255076
# 25%    9.920100e+05  183944.000000      40.671511     -73.972030
# 50%    1.004606e+06  205315.000000      40.730145     -73.926559
# 75%    1.016539e+06  234877.000000      40.811337     -73.883452
# max    1.067186e+06  271820.000000      40.912723     -73.700717

# %%
for col in df1.columns:
    print('{} : {}'.format(col,df1[col].unique()))
# Out:
# CMPLNT_NUM : [224807992 289768995 533585687 ... 916467724 548834543 797990974]
# CMPLNT_FR_DT : ['11/24/2015' '10/17/2014' '10/7/2014' ... '7/21/2008' '2/7/2012'
#  '7/19/2004']
# CMPLNT_FR_TM : ['16:00:00' '17:00:00' '22:30:00' ... '7:31:00' '5:52:00' '6:36:00']
# CMPLNT_TO_DT : [nan '10/17/2014' '10/7/2014' ... '12/20/2010' '7/21/2009' '12/1/2006']
# CMPLNT_TO_TM : [nan '17:03:00' '22:38:00' ... '6:39:00' '5:57:00' '6:29:00']
# RPT_DT : ['11/24/2015' '10/18/2014' '10/8/2014' '4/16/2014' '6/3/2014' '5/23/2014'
#  '9/18/2015' '11/5/2015' '11/19/2015' '11/25/2014' '12/8/2013'
#  '11/14/2014' '6/24/2014' '11/10/2015' '3/11/2015' '7/26/2015' '4/24/2014'
#  '12/28/2014' '2/9/2015' '2/22/2015' '1/14/2014' '6/6/2015' '3/28/2014'
#  '7/12/2015' '5/2/2015' '1/3/2015' '2/17/2014' '12/21/2013' '7/7/2015'
#  '2/12/2015' '10/28/2014' '9/2/2015' '5/25/2014' '11/18/2013' '3/2/2014'
#  '12/4/2015' '7/19/2015' '11/24/2013' '8/8/2015' '6/20/2014' '1/24/2015'
#  '5/23/2015' '9/24/2014' '1/13/2015' '6/5/2015' '10/7/2015' '7/9/2014'
#  '12/18/2013' '11/2/2013' '11/26/2014' '8/7/2015' '12/15/2013' '9/14/2014'
#  '12/4/2014' '10/24/2014' '9/22/2015' '9/11/2014' '10/5/2015' '1/23/2015'
#  '1/21/2014' '9/29/2014' '9/8/2014' '8/30/2015' '1/17/2014' '5/3/2014'
#  '12/2/2015' '3/30/2015' '11/27/2013' '5/10/2014' '11/6/2014' '7/31/2015'
#  '1/2/2014' '6/18/2014' '3/10/2014' '7/6/2014' '2/22/2014' '12/1/2013'
#  '9/10/2014' '7/29/2014' '6/9/2015' '11/22/2015' '2/20/2015' '4/10/2015'
#  '4/9/2014' '4/5/2015' '3/3/2015' '1/29/2014' '3/31/2014' '5/5/2014'
#  '7/27/2015' '10/6/2015' '9/16/2015' '6/7/2015' '4/27/2015' '1/18/2015'
#  '10/11/2014' '12/27/2015' '3/17/2014' '12/15/2014' '5/7/2015'
#  '11/26/2015' '7/15/2014' '2/4/2015' '6/23/2014' '10/9/2014' '5/19/2014'
#  '5/7/2014' '8/29/2014' '10/22/2014' '7/30/2014' '5/22/2015' '11/23/2013'
#  '9/4/2014' '7/1/2014' '5/21/2014' '4/17/2015' '5/31/2015' '10/20/2014'
#  '12/14/2014' '6/4/2015' '10/14/2015' '7/14/2014' '3/9/2014' '3/16/2015'
#  '3/16/2014' '8/1/2015' '6/13/2014' '3/6/2015' '5/19/2015' '11/25/2013'
#  '6/16/2014' '12/16/2013' '7/27/2014' '9/29/2015' '12/11/2015' '5/5/2015'
#  '12/13/2013' '9/28/2015' '8/26/2014' '10/19/2015' '9/15/2015' '5/26/2014'
#  '4/5/2014' '2/18/2015' '11/13/2013' '9/7/2015' '8/6/2014' '3/7/2015'
#  '10/13/2015' '6/22/2014' '4/17/2014' '11/29/2014' '2/27/2014' '4/22/2015'
#  '9/26/2015' '9/25/2015' '4/2/2014' '4/4/2015' '8/4/2014' '10/19/2014'
#  '8/8/2014' '8/22/2015' '8/12/2015' '11/4/2014' '2/16/2014' '5/30/2014'
#  '10/26/2014' '8/28/2014' '3/18/2015' '11/15/2013' '11/13/2014' '9/6/2014'
#  '12/21/2015' '4/19/2014' '11/13/2015' '1/26/2014' '3/4/2015' '12/9/2014'
#  '7/21/2015' '6/28/2015' '4/25/2014' '7/16/2015' '8/6/2015' '5/14/2014'
#  '10/10/2015' '4/13/2015' '8/17/2014' '6/4/2014' '10/17/2015' '5/27/2015'
#  '6/9/2014' '2/20/2014' '12/7/2013' '8/11/2015' '8/7/2014' '10/18/2015'
#  '5/17/2015' '11/5/2013' '11/11/2013' '10/2/2015' '4/21/2014' '2/24/2014'
#  '10/8/2015' '5/31/2014' '4/10/2014' '11/30/2014' '5/15/2015' '3/8/2015'
#  '11/6/2015' '6/27/2014' '9/26/2014' '5/28/2015' '6/8/2014' '4/18/2015'
#  '3/14/2015' '9/21/2015' '11/19/2014' '11/16/2015' '3/7/2014' '2/3/2014'
#  '6/29/2015' '12/16/2015' '5/16/2014' '3/15/2015' '8/16/2014' '3/31/2015'
#  '12/7/2015' '7/18/2015' '4/20/2015' '1/11/2014' '10/27/2014' '1/20/2015'
#  '11/1/2014' '12/27/2013' '11/21/2015' '11/21/2013' '10/25/2014'
#  '1/19/2014' '11/17/2013' '11/7/2013' '2/14/2015' '12/13/2015'
#  '11/14/2013' '3/6/2014' '3/15/2014' '11/3/2014' '5/21/2015' '8/29/2015'
#  '6/11/2015' '10/7/2014' '3/10/2015' '5/13/2014' '11/10/2013' '9/28/2014'
#  '1/24/2014' '10/15/2014' '3/26/2015' '7/25/2014' '2/10/2015' '9/15/2014'
#  '10/31/2014' '10/1/2014' '5/15/2014' '6/29/2014' '4/29/2014' '9/3/2014'
#  '10/22/2015' '9/17/2015' '9/23/2014' '10/24/2015' '2/5/2014' '10/25/2015'
#  '1/15/2015' '3/19/2014' '11/5/2014' '4/22/2014' '9/1/2015' '6/20/2015'
#  '3/22/2014' '6/25/2014' '10/12/2014' '12/30/2013' '10/4/2015' '10/1/2015'
#  '7/24/2014' '3/14/2014' '7/28/2014' '6/27/2015' '11/30/2015' '9/9/2015'
#  '6/24/2015' '1/15/2014' '6/14/2014' '3/1/2014' '2/28/2015' '2/25/2014'
#  '1/3/2014' '2/17/2015' '2/15/2015' '2/21/2014' '3/9/2015' '4/11/2015'
#  '2/19/2014' '9/19/2015' '5/9/2015' '7/18/2014' '1/12/2014' '10/27/2015'
#  '11/27/2015' '1/8/2015' '12/6/2015' '8/5/2014' '9/2/2014' '3/18/2014'
#  '5/11/2015' '11/23/2014' '4/7/2014' '7/24/2015' '11/8/2014' '1/6/2015'
#  '11/28/2014' '4/8/2014' '1/1/2014' '7/8/2015' '10/2/2014' '8/9/2015'
#  '9/4/2015' '12/12/2013' '9/30/2014' '8/22/2014' '4/8/2015' '12/20/2014'
#  '12/10/2015' '1/9/2014' '9/27/2015' '4/18/2014' '2/9/2014' '7/28/2015'
#  '5/29/2014' '10/16/2015' '10/17/2014' '5/17/2014' '7/19/2014' '5/20/2015'
#  '6/15/2014' '5/24/2015' '5/6/2014' '3/21/2015' '4/26/2014' '5/27/2014'
#  '3/20/2014' '7/3/2014' '5/20/2014' '12/18/2015' '2/19/2015' '2/8/2014'
#  '4/15/2014' '12/26/2015' '8/15/2015' '3/2/2015' '4/26/2015' '12/14/2015'
#  '12/10/2014' '9/30/2015' '12/26/2013' '8/13/2014' '12/22/2015'
#  '11/8/2015' '6/25/2015' '4/30/2014' '11/4/2013' '3/20/2015' '6/2/2014'
#  '5/4/2014' '9/5/2015' '10/28/2015' '10/23/2014' '11/17/2014' '10/12/2015'
#  '9/22/2014' '11/17/2015' '5/14/2015' '7/12/2014' '7/13/2014' '12/26/2014'
#  '10/26/2015' '11/11/2015' '3/25/2015' '7/9/2015' '6/7/2014' '9/7/2014'
#  '9/18/2014' '1/26/2015' '12/25/2013' '1/30/2014' '9/24/2015' '4/1/2014'
#  '7/31/2014' '8/1/2014' '11/20/2015' '12/28/2013' '8/20/2014' '4/6/2015'
#  '2/7/2015' '1/13/2014' '8/2/2015' '4/28/2015' '4/11/2014' '12/23/2014'
#  '12/1/2015' '11/14/2015' '6/11/2014' '9/17/2014' '5/2/2014' '2/7/2014'
#  '5/8/2015' '2/23/2014' '11/24/2014' '12/24/2015' '10/4/2014' '6/23/2015'
#  '6/26/2014' '9/10/2015' '8/5/2015' '12/27/2014' '12/31/2014' '3/11/2014'
#  '8/16/2015' '1/2/2015' '9/16/2014' '12/30/2015' '3/25/2014' '11/18/2015'
#  '2/6/2015' '11/3/2015' '12/28/2015' '11/8/2013' '8/13/2015' '1/27/2015'
#  '1/10/2014' '10/23/2015' '12/3/2013' '5/3/2015' '12/5/2013' '10/31/2015'
#  '12/12/2015' '10/3/2015' '8/11/2014' '8/9/2014' '1/28/2014' '5/25/2015'
#  '12/17/2013' '9/20/2015' '8/18/2014' '12/25/2015' '11/25/2015'
#  '11/6/2013' '1/21/2015' '1/25/2015' '8/21/2015' '9/12/2014' '6/8/2015'
#  '7/20/2015' '6/17/2015' '9/13/2015' '11/22/2013' '10/20/2015' '4/14/2015'
#  '12/22/2014' '9/5/2014' '8/10/2015' '7/15/2015' '6/19/2014' '10/21/2014'
#  '1/5/2014' '7/30/2015' '12/20/2013' '12/21/2014' '11/12/2014' '5/29/2015'
#  '10/30/2014' '4/9/2015' '4/1/2015' '7/7/2014' '3/13/2015' '10/9/2015'
#  '7/26/2014' '9/12/2015' '2/10/2014' '9/13/2014' '4/21/2015' '5/8/2014'
#  '4/6/2014' '3/12/2015' '12/19/2013' '12/4/2013' '1/18/2014' '11/21/2014'
#  '8/25/2015' '11/19/2013' '8/26/2015' '9/27/2014' '7/5/2014' '6/21/2015'
#  '4/4/2014' '1/10/2015' '11/3/2013' '7/13/2015' '12/29/2013' '12/7/2014'
#  '2/27/2015' '7/29/2015' '8/24/2014' '11/7/2015' '6/12/2014' '6/1/2015'
#  '12/23/2015' '6/5/2014' '5/12/2015' '4/23/2015' '6/21/2014' '7/2/2014'
#  '11/2/2015' '6/15/2015' '9/1/2014' '12/20/2015' '1/6/2014' '5/9/2014'
#  '5/10/2015' '4/19/2015' '8/10/2014' '8/18/2015' '6/22/2015' '11/22/2014'
#  '12/2/2013' '12/17/2015' '2/14/2014' '2/4/2014' '4/23/2014' '5/18/2015'
#  '12/19/2014' '7/17/2014' '9/25/2014' '6/6/2014' '9/3/2015' '11/26/2013'
#  '12/30/2014' '8/21/2014' '1/25/2014' '11/11/2014' '2/26/2014'
#  '12/11/2014' '11/20/2013' '6/10/2014' '7/23/2015' '10/3/2014' '4/12/2015'
#  '7/25/2015' '2/28/2014' '1/4/2014' '8/23/2015' '11/23/2015' '4/3/2014'
#  '1/19/2015' '11/18/2014' '7/23/2014' '12/8/2014' '12/10/2013' '6/30/2015'
#  '12/22/2013' '6/1/2014' '11/10/2014' '6/10/2015' '1/14/2015' '5/6/2015'
#  '12/19/2015' '11/15/2015' '10/29/2014' '11/9/2014' '9/23/2015' '9/9/2014'
#  '2/18/2014' '12/5/2015' '8/2/2014' '12/23/2013' '3/24/2015' '10/5/2014'
#  '6/16/2015' '3/5/2015' '4/12/2014' '1/20/2014' '7/6/2015' '12/9/2013'
#  '4/3/2015' '5/30/2015' '12/31/2015' '7/22/2015' '7/10/2015' '3/21/2014'
#  '4/2/2015' '10/10/2014' '2/13/2015' '11/30/2013' '3/22/2015' '7/16/2014'
#  '11/7/2014' '4/20/2014' '3/17/2015' '8/31/2014' '2/1/2014' '5/18/2014'
#  '5/26/2015' '3/12/2014' '8/28/2015' '1/12/2015' '11/16/2013' '2/24/2015'
#  '12/9/2015' '12/24/2013' '5/11/2014' '1/9/2015' '12/13/2014' '1/23/2014'
#  '2/12/2014' '9/20/2014' '12/1/2014' '4/15/2015' '11/1/2015' '8/20/2015'
#  '9/8/2015' '2/13/2014' '11/15/2014' '3/4/2014' '4/13/2014' '1/16/2015'
#  '7/14/2015' '10/15/2015' '1/22/2015' '4/30/2015' '11/9/2013' '4/25/2015'
#  '8/27/2014' '8/12/2014' '12/18/2014' '7/11/2015' '11/29/2015' '5/24/2014'
#  '1/27/2014' '3/29/2015' '7/3/2015' '12/8/2015' '8/19/2015' '5/22/2014'
#  '10/13/2014' '7/21/2014' '1/8/2014' '6/3/2015' '9/14/2015' '1/31/2015'
#  '6/26/2015' '12/29/2015' '10/30/2015' '6/2/2015' '5/1/2015' '3/27/2014'
#  '3/23/2015' '12/11/2013' '11/9/2015' '4/16/2015' '1/31/2014' '10/6/2014'
#  '12/17/2014' '6/30/2014' '11/16/2014' '10/11/2015' '12/3/2014' '1/1/2015'
#  '11/29/2013' '10/16/2014' '7/4/2014' '8/3/2015' '11/12/2015' '1/11/2015'
#  '2/8/2015' '1/30/2015' '7/11/2014' '8/17/2015' '3/5/2014' '2/6/2014'
#  '12/31/2013' '9/6/2015' '8/3/2014' '3/27/2015' '10/29/2015' '3/23/2014'
#  '9/21/2014' '12/25/2014' '12/12/2014' '7/5/2015' '8/24/2015' '8/27/2015'
#  '4/27/2014' '6/12/2015' '9/19/2014' '3/30/2014' '2/1/2015' '3/19/2015'
#  '12/6/2014' '5/12/2014' '7/17/2015' '1/7/2015' '4/29/2015' '7/20/2014'
#  '8/23/2014' '12/6/2013' '8/25/2014' '8/14/2014' '2/25/2015' '7/10/2014'
#  '2/11/2014' '12/15/2015' '3/13/2014' '8/19/2014' '11/28/2015' '6/13/2015'
#  '6/17/2014' '1/22/2014' '11/20/2014' '4/24/2015' '2/21/2015' '9/11/2015'
#  '2/15/2014' '4/7/2015' '6/28/2014' '2/26/2015' '1/17/2015' '4/28/2014'
#  '12/16/2014' '1/5/2015' '11/4/2015' '3/3/2014' '3/26/2014' '12/5/2014'
#  '11/28/2013' '5/4/2015' '7/1/2015' '8/14/2015' '1/16/2014' '12/3/2015'
#  '8/30/2014' '12/24/2014' '3/28/2015' '10/21/2015' '2/5/2015' '6/14/2015'
#  '5/1/2014' '10/14/2014' '11/12/2013' '2/23/2015' '5/16/2015' '7/8/2014'
#  '11/27/2014' '3/8/2014' '5/28/2014' '5/13/2015' '3/1/2015' '12/2/2014'
#  '1/29/2015' '1/28/2015' '8/15/2014' '2/11/2015' '3/29/2014' '7/22/2014'
#  '11/2/2014' '7/4/2015' '12/14/2013' '2/2/2015' '1/7/2014' '6/19/2015'
#  '8/4/2015' '3/24/2014' '7/2/2015' '2/16/2015' '2/2/2014' '2/3/2015'
#  '4/14/2014' '8/31/2015' '1/4/2015' '12/29/2014' '6/18/2015' '11/1/2013'
#  '10/11/2013' '10/4/2013' '10/26/2013' '10/2/2013' '10/7/2013' '10/6/2013'
#  '10/10/2013']
# KY_CD : [112 341 121 232 351 109 105 106 578 361 235 107 359 344 236 113 348 110
#  233 347 126 118 111 353 117 124 104 358 352 355 114 340 678 360 125 101
#  343 365 115 231 572 116 346 364 103 230 238 345 363 120 342 350 675 356
#  237 122 119 677 354 571 676 366 455 357 349 234 102 881 123 577 685]
# OFNS_DESC : ['THEFT-FRAUD' 'PETIT LARCENY' 'CRIMINAL MISCHIEF & RELATED OF'
#  'POSSESSION OF STOLEN PROPERTY' 'GRAND LARCENY' 'ROBBERY'
#  'FELONY ASSAULT' 'HARRASSMENT 2' 'OFF. AGNST PUB ORD SENSBLTY &'
#  'DANGEROUS DRUGS' 'BURGLARY' 'OFFENSES AGAINST PUBLIC ADMINI'
#  'ASSAULT 3 & RELATED OFFENSES' 'DANGEROUS WEAPONS' 'FORGERY'
#  'VEHICLE AND TRAFFIC LAWS' 'GRAND LARCENY OF MOTOR VEHICLE' 'SEX CRIMES'
#  'INTOXICATED & IMPAIRED DRIVING' nan 'UNAUTHORIZED USE OF A VEHICLE'
#  'MISCELLANEOUS PENAL LAW' 'KIDNAPPING & RELATED OFFENSES' 'RAPE'
#  'OFFENSES INVOLVING FRAUD' 'CRIMINAL TRESPASS'
#  'OFFENSES AGAINST THE PERSON' 'ARSON' 'FRAUDS'
#  'NYS LAWS-UNCLASSIFIED FELONY' 'MURDER & NON-NEGL. MANSLAUGHTER'
#  'OTHER OFFENSES RELATED TO THEF' 'ADMINISTRATIVE CODE'
#  'PROSTITUTION & RELATED OFFENSES' "BURGLAR'S TOOLS" 'DISORDERLY CONDUCT'
#  'ALCOHOLIC BEVERAGE CONTROL LAW' 'OTHER STATE LAWS (NON PENAL LA'
#  'HOMICIDE-NEGLIGENT,UNCLASSIFIE' 'JOSTLING' 'THEFT OF SERVICES'
#  'FRAUDULENT ACCOSTING' 'OFFENSES RELATED TO CHILDREN'
#  'OFFENSES AGAINST PUBLIC SAFETY' 'CHILD ABANDONMENT/NON SUPPORT'
#  'PETIT LARCENY OF MOTOR VEHICLE' 'GAMBLING' 'ESCAPE 3'
#  'ENDAN WELFARE INCOMP' 'INTOXICATED/IMPAIRED DRIVING' 'OTHER STATE LAWS'
#  'AGRICULTURE & MRKTS LAW-UNCLASSIFIED' 'ANTICIPATORY OFFENSES'
#  'LOITERING/GAMBLING (CARDS, DIC' 'NEW YORK CITY HEALTH CODE'
#  'NYS LAWS-UNCLASSIFIED VIOLATION' 'UNLAWFUL POSS. WEAP. ON SCHOOL'
#  'FORTUNE TELLING' 'DISRUPTION OF A RELIGIOUS SERV'
#  'HOMICIDE-NEGLIGENT-VEHICLE' 'OTHER TRAFFIC INFRACTION'
#  'OTHER STATE LAWS (NON PENAL LAW)' 'ABORTION'
#  'UNDER THE INFLUENCE OF DRUGS' 'KIDNAPPING AND RELATED OFFENSES'
#  'ADMINISTRATIVE CODES']
# PD_CD : [739. 339. 269. 490. 259. 421. 386. 109. 638. 639. 567. 268. 443. 221.
#  749. 256. 258. 637. 343. 114. 101. 321. 397. 569. 782. 113. 333. 725.
#  916. 388. 338. 403. 451. 254. 441. 175. 905. 594. 508. 511. 412. 401.
#  792. 411. 406. 759. 349. 418. 223. 494. 462. 198. 426. 439. 681. 793.
#  503. 922. 489. 750. 183. 155. 705. 729. 205. 117. 105. 404. 414. 419.
#  760. 213. 384. 181. 263. 707. 301. 509. 307. 500. 521. 402. 457. 718.
#  417. 566. 433. 661. 407. 422. 267. 408. 115. 313. 847. 405. 157. 420.
#  415. 424.  nan 106. 357. 438. 410. 335. 390. 748. 224. 510. 203. 416.
#  398. 344. 478. 201. 409. 170. 191. 389. 243. 425. 437. 878. 461. 501.
#  779. 640. 273. 211. 584. 277. 159. 209. 399. 361. 303. 382. 625. 231.
#  761. 596. 432. 168. 177. 197. 719. 665. 568. 502. 305. 214. 515. 179.
#  802. 809. 711. 391. 234. 727. 808. 199. 264. 744. 233. 430. 531. 435.
#  423. 125. 111. 464. 475. 848. 649. 466. 683. 392. 918. 788. 455. 380.
#  731. 723. 695. 701. 841. 366. 244. 351. 708. 375. 548. 377. 514. 193.
#  434. 652. 858. 379. 644. 271. 811. 493. 696. 110. 241. 367. 812. 153.
#  563. 770. 544. 428. 347. 479. 789. 663. 442. 512. 907. 507. 659. 647.
#  505. 112. 185. 266. 365. 799. 764. 730. 477. 360. 742. 570. 553. 180.
#  772. 703. 781. 565. 450. 643. 363. 195. 327. 645. 698. 204. 904. 849.
#  520. 633. 371. 385. 350. 395. 329. 766. 818. 431. 674. 662. 672. 762.
#  297. 166. 844. 519. 724. 164. 394. 341. 293. 746. 610. 104. 879. 393.
#  862. 706. 591. 890. 641. 889. 669. 187. 498. 585. 176. 174. 491. 754.
#  697. 289. 688. 817. 648. 605. 261. 331. 532. 557. 780. 786. 899. 845.
#  323. 445. 687. 880. 820. 756. 107. 887. 586. 840. 826. 843. 523. 888.
#  381. 595. 468. 291. 861. 345. 694. 627. 373. 524. 853. 821. 576. 721.
#  122. 874. 529. 186. 396. 969. 827. 143. 588. 797. 281. 533. 537. 775.
#  864. 622. 184. 587. 646. 265. 814. 975. 342. 285. 872. 715. 846.]
# PD_DESC : ['FRAUD,UNCLASSIFIED-FELONY' 'LARCENY,PETIT FROM OPEN AREAS,'
#  'MISCHIEF,CRIMINAL,    UNCL 2ND' 'STOLEN PROPERTY 3,POSSESSION'
#  'CRIMINAL MISCHIEF,UNCLASSIFIED 4'
#  'LARCENY,GRAND FROM VEHICLE/MOTORCYCLE'
#  'ROBBERY,PERSONAL ELECTRONIC DEVICE' 'ASSAULT 2,1,UNCLASSIFIED'
#  'HARASSMENT,SUBD 3,4,5' 'AGGRAVATED HARASSMENT 2'
#  'MARIJUANA, POSSESSION 4 & 5' 'CRIMINAL MIS 2 & 3'
#  'LARCENY,GRAND OF BICYCLE' 'BURGLARY,RESIDENCE,DAY'
#  'VIOLATION OF ORDER OF PROTECTI' 'MISCHIEF, CRIMINAL 4, BY FIRE'
#  'CRIMINAL MISCHIEF 4TH, GRAFFIT' 'HARASSMENT,SUBD 1,CIVILIAN'
#  'LARCENY,PETIT OF BICYCLE' 'OBSTR BREATH/CIRCUL' 'ASSAULT 3'
#  'LARCENY,PETIT FROM AUTO' 'ROBBERY,OPEN AREA UNCLASSIFIED'
#  'MARIJUANA, SALE 4 & 5' 'WEAPONS, POSSESSION, ETC'
#  'MENACING,UNCLASSIFIED' 'LARCENY,PETIT FROM STORE-SHOPL'
#  'FORGERY,M.V. REGISTRATION' 'LEAVING SCENE-ACCIDENT-PERSONA'
#  'ROBBERY,RESIDENTIAL COMMON AREA' 'LARCENY,PETIT FROM BUILDING,UN'
#  'LARCENY,GRAND BY BANK ACCT COMPROMISE-REPRODUCED CHECK'
#  'LARCENY,GRAND OF MOTORCYCLE' 'MISCHIEF, CRIMINAL 4, OF MOTOR'
#  'LARCENY,GRAND OF AUTO' 'SEXUAL ABUSE 3,2' 'INTOXICATED DRIVING,ALCOHOL'
#  'OBSCENITY 1' 'DRUG PARAPHERNALIA,   POSSESSE'
#  'CONTROLLED SUBSTANCE, POSSESSI'
#  'LARCENY,GRAND FROM RESIDENCE, UNATTENDED'
#  'LARCENY,GRAND BY ACQUIRING LOS' 'WEAPONS POSSESSION 1 & 2'
#  'LARCENY,GRAND FROM EATERY, UNATTENDED'
#  'LARCENY,GRAND FROM PERSON, BAG OPEN/DIP'
#  'PUBLIC ADMINISTATION,UNCLASS M' 'LARCENY,PETIT OF LICENSE PLATE'
#  'LARCENY,GRAND BY ACQUIRING LOST CREDIT CARD' 'BURGLARY,RESIDENCE,NIGHT'
#  'STOLEN PROPERTY 2,1,POSSESSION' 'UNAUTHORIZED USE VEHICLE 3'
#  'CRIMINAL CONTEMPT 1' 'LARCENY,GRAND BY BANK ACCT COMPROMISE-TELLER'
#  'LARCENY,GRAND FROM OPEN AREAS, UNATTENDED' 'CHILD, ENDANGERING WELFARE'
#  'WEAPONS POSSESSION 3' 'CONTROLLED SUBSTANCE,INTENT TO'
#  'TRAFFIC,UNCLASSIFIED MISDEMEAN' 'THEFT,RELATED OFFENSES,UNCLASS'
#  'RESISTING ARREST' 'IMPRISONMENT 1,UNLAWFUL' 'RAPE 2'
#  'FORGERY,ETC.-MISD.' 'FORGERY,ETC.,UNCLASSIFIED-FELO'
#  'TRESPASS 2, CRIMINAL' 'RECKLESS ENDANGERMENT 1' 'STRANGULATION 1ST'
#  'LARCENY,GRAND FROM PERSON,PERSONAL ELECTRONIC DEVICE(SNATCH)'
#  'LARCENY,GRAND PERSON,NECK CHAI' 'LARCENY,GRAND FROM PERSON,UNCL'
#  'BRIBERY,PUBLIC ADMINISTRATION' 'BURGLARY,COMMERCIAL,NIGHT'
#  'ROBBERY,POCKETBOOK/CARRIED BAG' 'IMPRISONMENT 2,UNLAWFUL' 'ARSON 2,3,4'
#  'IMPERSONATION 2, PUBLIC SERVAN' 'LARCENY,PETIT BY ACQUIRING LOS'
#  'POSSESSION HYPODERMIC INSTRUME' 'LARCENY,PETIT BY DISHONEST EMP'
#  'CONTROLLED SUBSTANCE,POSSESS.' 'CONTROLLED SUBSTANCE, SALE 5'
#  'LARCENY,GRAND BY FALSE PROMISE-NOT IN PERSON CONTACT'
#  'LARCENY,GRAND OF VEHICULAR/MOTORCYCLE ACCESSORIES'
#  'FRAUD,UNCLASSIFIED-MISDEMEANOR' 'LARCENY,GRAND FROM PERSON,PURS'
#  'MARIJUANA, POSSESSION' 'LARCENY,GRAND FROM STORE-SHOPL'
#  'LEWDNESS,PUBLIC' 'LARCENY,GRAND BY DISHONEST EMP'
#  'LARCENY,GRAND BY OPEN CREDIT CARD (NEW ACCT)'
#  'MISCHIEF, CRIMINAL 3 & 2, OF M'
#  'LARCENY,GRAND FROM PERSON,LUSH WORKER(SLEEPING/UNCON VICTIM)'
#  'RECKLESS ENDANGERMENT 2' 'LARCENY,PETIT BY FALSE PROMISE'
#  'NY STATE LAWS,UNCLASSIFIED FEL' 'LARCENY,GRAND BY THEFT OF CREDIT CARD'
#  'RAPE 1' 'LARCENY,GRAND BY OPEN/COMPROMISE CELL PHONE ACCT'
#  'LARCENY,GRAND FROM PERSON,PICK'
#  'LARCENY,GRAND BY CREDIT CARD ACCT COMPROMISE-EXISTING ACCT' nan
#  'ASSAULT 2,1,PEACE OFFICER' 'LARCENY,PETIT OF VEHICLE ACCES'
#  'LARCENY,GRAND FROM BUILDING (NON-RESIDENCE) UNATTENDED'
#  'LARCENY,GRAND FROM RETAIL STORE, UNATTENDED' 'LARCENY,PETIT FROM TRUCK'
#  'ROBBERY,HOME INVASION' 'CONTEMPT,CRIMINAL'
#  'BURGLARY,RESIDENCE,UNKNOWN TIM' 'CONTROLLED SUBSTANCE, INTENT T'
#  'TRESPASS 3, CRIMINAL' 'LARCENY,GRAND FROM NIGHT CLUB, UNATTENDED'
#  'ROBBERY,PUBLIC PLACE INSIDE' 'PETIT LARCENY OF ANIMAL'
#  'THEFT OF SERVICES, UNCLASSIFIE' 'TRESPASS 4,CRIMINAL SUB 2'
#  'LARCENY,GRAND BY EXTORTION' 'SEXUAL MISCONDUCT,INTERCOURSE'
#  'CUSTODIAL INTERFERENCE 2' 'ROBBERY,DWELLING'
#  'BURGLARY,UNCLASSIFIED,NIGHT'
#  'LARCENY,GRAND BY BANK ACCT COMPROMISE-ATM TRANSACTION'
#  'LARCENY,GRAND BY FALSE PROMISE-IN PERSON CONTACT'
#  'ADM.CODE,UNCLASSIFIED MISDEMEA' 'UNAUTHORIZED USE VEHICLE 2'
#  'PUBLIC ADMINISTRATION,UNCLASSI' 'AGGRAVATED HARASSMENT 1'
#  'TAMPERING 1,CRIMINAL' 'BURGLARY,COMMERCIAL,DAY'
#  'PROSTITUTION 3, PROMOTING UNDE' 'RECKLESS ENDANGERMENT OF PROPE'
#  'RAPE 1,ATTEMPT' 'BURGLARS TOOLS,UNCLASSIFIED'
#  'ROBBERY,COMMERCIAL UNCLASSIFIED' 'ROBBERY,BANK'
#  'LARCENY,PETIT BY CHECK USE' 'ROBBERY,NECKCHAIN/JEWELRY'
#  'DISORDERLY CONDUCT' 'BURGLARY,TRUCK DAY' 'BRIBERY, POLICE OFFICER'
#  'OBSCENE MATERIAL - UNDER 17 YE'
#  'LARCENY,GRAND BY IDENTITY THEFT-UNCLASSIFIED' 'SODOMY 1' 'SEXUAL ABUSE'
#  'COERCION 1' 'MAKING TERRORISTIC THREAT' 'MARIJUANA, POSSESSION 1, 2 & 3'
#  'LARCENY,PETIT BY CREDIT CARD U' 'BURGLARY,COMMERCIAL,UNKNOWN TI'
#  'CONTROLLED SUBSTANCE,SALE 3' 'AGGRAVATED SEXUAL ASBUSE'
#  'ALCOHOLIC BEVERAGE CONTROL LAW' 'TAX LAW' 'TAMPERING WITH A WITNESS'
#  'ROBBERY,LICENSED MEDALLION CAB' 'BURGLARY,UNKNOWN TIME'
#  'FORGERY,PRESCRIPTION' 'AGGRAVATED CRIMINAL CONTEMPT'
#  'ARSON, MOTOR VEHICLE 1 2 3 & 4' 'BAIL JUMPING 3' 'BURGLARY,TRUCK NIGHT'
#  'LARCENY,GRAND BY BANK ACCT COMPROMISE-UNCLASSIFIED'
#  'LARCENY,GRAND FROM TRUCK, UNATTENDED'
#  'LARCENY,GRAND FROM BOAT, UNATTENDED' 'HOMICIDE,NEGLIGENT,UNCLASSIFIE'
#  'MENACING,PEACE OFFICER' 'JOSTLING' 'UNAUTH. SALE OF TRANS. SERVICE'
#  'NY STATE LAWS,UNCLASSIFIED MIS' 'FALSE REPORT UNCLASSIFIED'
#  'ACCOSTING,FRAUDULENT' 'CHILD,ALCOHOL SALE TO'
#  'ROBBERY,UNLICENSED FOR HIRE VEHICLE' 'RECKLESS DRIVING'
#  'FIREWORKS, SALE' 'LARCENY,GRAND OF TRUCK' 'ROBBERY,CAR JACKING'
#  'SALE OF UNAUTHORIZED RECORDING' 'FORGERY,DRIVERS LICENSE'
#  'CHILD ABANDONMENT' 'BRIBERY,COMMERCIAL' 'PUBLIC HEALTH LAW,UNCLASSIFIED'
#  'ROBBERY,BICYCLE' 'BURGLARY,UNCLASSIFIED,UNKNOWN'
#  'LARCENY,PETIT OF MOTORCYCLE' 'IMPERSONATION 1, POLICE OFFICE'
#  'ROBBERY,PHARMACY' 'GAMBLING, DEVICE, POSSESSION'
#  'ROBBERY,BODEGA/CONVENIENCE STORE' 'CONTROLLED SUBSTANCE,SALE 2'
#  'CUSTODIAL INTERFERENCE 1' 'LARCENY,GRAND BY OPEN BANK ACCT'
#  'RIOT 2/INCITING' 'IMITATION PISTOL/AIR RIFLE' 'ROBBERY,GAS STATION'
#  'FALSE REPORT 1,FIRE' 'TAMPERING 3,2, CRIMINAL' 'DOG STEALING'
#  'STOLEN PROPERTY-MOTOR VEH 2ND,' 'PROMOTING A SEXUAL PERFORMANCE'
#  'MENACING 1ST DEGREE (VICT PEAC' 'BURGLARY,UNCLASSIFIED,DAY'
#  'ROBBERY, CHAIN STORE' 'AGRICULTURE & MARKETS LAW,UNCL' 'RAPE 3'
#  'PROSTITUTION' 'COMPUTER UNAUTH. USE/TAMPER'
#  'GAMBLING 2,PROMOTING,UNCLASSIF'
#  'LARCENY,GRAND BY BANK ACCT COMPROMISE-UNAUTHORIZED PURCHASE'
#  'PETIT LARCENY-CHECK FROM MAILB' 'FIREWORKS, POSSESS/USE'
#  'SUPP. ACT TERR 2ND' 'LARCENY, GRAND OF AUTO - ATTEM'
#  'CONTROLLED SUBSTANCE,SALE 1' 'IMPAIRED DRIVING,DRUG'
#  'NUISANCE,CRIMINAL,UNCLASSIFIED' 'FALSE REPORT BOMB'
#  'MENACING 1ST DEGREE (VICT NOT' 'KIDNAPPING 2'
#  'MISCHIEF, CRIMINAL 3&2, BY FIR' 'ROBBERY,LIQUOR STORE'
#  'PUBLIC SAFETY,UNCLASSIFIED MIS' 'BAIL JUMPING 1 & 2'
#  'MANUFACTURE UNAUTHORIZED RECOR' 'THEFT OF SERVICES- CABLE TV SE'
#  'ROBBERY,ATM LOCATION' 'ESCAPE 3' 'MARIJUANA, SALE 1, 2 & 3'
#  'GAMBLING 1,PROMOTING,BOOKMAKIN' 'COURSE OF SEXUAL CONDUCT AGAIN'
#  'COMPUTER TAMPER/TRESSPASS' 'CHECK,BAD' 'CRIMINAL DISPOSAL FIREARM 1 &'
#  'PROSTITUTION, PATRONIZING 4, 3' 'LARCENY, GRAND OF MOPED'
#  'ASSEMBLY,UNLAWFUL' 'ROBBERY,BAR/RESTAURANT' 'COERCION 2'
#  'LARCENY,PETIT FROM PARKING MET' 'FALSE ALARM FIRE'
#  'INCOMPETENT PERSON,KNOWINGLY ENDANGERING' 'TRESPASS 1,CRIMINAL'
#  'NY STATE LAWS,UNCLASSIFIED VIO' 'CONTROLLED SUBSTANCE, SALE 4'
#  'EXPOSURE OF A PERSON' 'ROBBERY,CHECK CASHING BUSINESS'
#  'ROBBERY, PAYROLL' 'LARCENY, PETIT OF MOPED'
#  'ROBBERY,ON BUS/ OR BUS DRIVER' 'LARCENY,PETIT FROM COIN MACHIN'
#  'PERJURY 2,1,ETC' 'ABANDON ANIMAL' 'LARCENY,GRAND FROM PIER, UNATTENDED'
#  'EAVESDROPPING' 'MATERIAL              OFFENSIV' 'RIOT 1' 'ESCAPE 2,1'
#  'FACILITATION 4, CRIMINAL' 'SODOMY 2' 'CAUSE SPI/KILL ANIMAL'
#  'SALE SCHOOL GROUNDS 4' 'FORGERY-ILLEGAL POSSESSION,VEH' 'SODOMY 3'
#  'ROBBERY,LICENSED FOR HIRE VEHICLE' 'LARCENY,PETIT OF AUTO'
#  'CONSPIRACY 2, 1' 'PERJURY 3,ETC.' 'LOITERING,GAMBLING,OTHER'
#  'VEHICULAR ASSAULT (INTOX DRIVE' 'ADM.CODE,UNCLASSIFIED VIOLATIO'
#  'ROBBERY,OF TRUCK DRIVER' 'ALCOHOLIC BEVERAGES,PUBLIC CON'
#  'RECORDS,FALSIFY-TAMPER' 'OBSCENITY, PERFORMANCE 3'
#  'N.Y.C. TRANSIT AUTH. R&R' 'HEALTHCARE/RENT.REG.' 'HEALTH CODE,VIOLATION'
#  'PRIVACY,OFFENSES AGAINST,UNCLA' 'KIDNAPPING 1'
#  'STOLEN PROPERTY 2,POSSESSION B' 'PROSTITUTION 3,PROMOTING BUSIN'
#  'SEX CRIMES' 'SEXUAL MISCONDUCT,DEVIATE' 'STOLEN PROP-MOTOR VEHICLE 3RD,'
#  'APPEARANCE TICKET FAIL TO RESP' 'USE OF A CHILD IN A SEXUAL PER'
#  'CONSPIRACY 6, 5' 'INCOMPETENT PERSON,RECKLESSY ENDANGERING'
#  'TORTURE/INJURE ANIMAL CRUELTY' 'PLACE FALSE BOMB'
#  'LOITERING TO PROMOTE PROSTITUT' 'ARSON 1' 'LARCENY,PETIT FROM PIER'
#  'GAMBLING 1,PROMOTING,POLICY' 'NUISANCE, CRIMINAL'
#  'WEAPONS,PROHIBITED USE' 'PARKR&R,UNCLASSIFIED VIOLATION'
#  'BREED/TRAIN/HOST ANIMAL FIGHTING' 'LARCENY,PETIT FROM BOAT'
#  'LARCENY,GRAND OF BOAT' 'CHILD,OFFENSES AGAINST,UNCLASS'
#  'POSSES OR CARRY A KNIFE' 'EDUCATION LAW, TRUANCY'
#  'ABSCONDING FROM WORK RELEASE 2' 'END WELFARE VULNERABLE ELDERLY PERSON'
#  'GRAFFITI (ADMINISTRATIVE CODE-' 'SEX TRAFFICKING'
#  'PUBLIC HEALTH LAW,GLUE,UNLAWFU' 'GENERAL BUSINESS LAW,TICKET SP'
#  'INAPPROPIATE SHELTER DOG LEFT' 'SALE SCHOOL GROUNDS'
#  'HEALTH CODE,UNCLASSIFIED MISDE' 'ROBBERY,HIJACKING'
#  'UNLAWFUL POSS. WEAPON UPON SCH' 'FORTUNE TELLING' 'CONSPIRACY 4, 3'
#  'AIRPOLLUTION' 'LARCENY,PETIT OF BOAT' 'INCEST' 'DIS. CON.,AGGRAVATED'
#  'ROBBERY,DOCTOR/DENTIST OFFICE' 'CONTROLLED SUBSTANCE,POSSESS.-'
#  'CIGARETTE,NO TAX STAMP,POSSESS' 'EDUCATION LAW,UNCLASSIFIED'
#  'PROSTITUTION 4,PROMOTING&SECUR' 'BRIBERY,FRAUD'
#  'HOMICIDE, NEGLIGENT, VEHICLE,' 'PEDDLING,UNLAWFUL'
#  'SALES OF PRESCRIPTION' 'LURING A CHILD' 'ROBBERY,BEGIN AS SHOPLIFTING'
#  'TRAFFIC,UNCLASSIFIED INFRACTIO' 'GENERAL BUSINESS LAW / UNCLASSIFIED'
#  'ABORTION 1' 'PROSTITUTION 2, UNDER 16' 'WOUNDS,REPORTING OF'
#  'SOLICITATION 5,CRIMINAL' 'GAMBLING 2, PROMOTING, BOOKMAK'
#  'GAMBLING 2, PROMOTING, POLICY-' 'MONEY LAUNDERING 1 & 2'
#  'BUILDING MATERIAL' 'UNDER THE INFLUENCE OF DRUGS' 'LABOR TRAFFICKING'
#  'PROSTITUTION 2, COMPULSORY' 'DISSEMINATING A FALSE SEX OFFEND'
#  'MISCHIEF 1,CRIMINAL,EXPLOSIVE' 'ATTEND/SPECTATOR ANIMAL FIGHTING'
#  'ENVIRONMENTAL CONTROL BOARD' 'LARCENY, PETIT OF AUTO - ATTEM'
#  'SOLICITATION 3,2,1, CRIMINAL' 'NOISE,UNECESSARY'
#  'POSSESSION ANTI-SECURITY ITEM' 'CONFINING ANIMAL IN VEHICLE/SHELTER']
# CRM_ATPT_CPTD_CD : ['COMPLETED' 'ATTEMPTED' nan]
# LAW_CAT_CD : ['FELONY' 'MISDEMEANOR' 'VIOLATION']
# JURIS_DESC : ['N.Y. POLICE DEPT' 'N.Y. TRANSIT POLICE' 'N.Y. HOUSING POLICE'
#  'DEPT OF CORRECTIONS' 'PORT AUTHORITY' 'OTHER' 'N.Y. STATE POLICE'
#  'HEALTH & HOSP CORP' 'TRI-BORO BRDG TUNNL' 'N.Y. STATE PARKS'
#  'METRO NORTH' 'POLICE DEPT NYC' 'AMTRACK' 'U.S. PARK POLICE' 'NYC PARKS'
#  'NEW YORK CITY SHERIFF OFFICE' 'CONRAIL' 'STATN IS RAPID TRANS'
#  'LONG ISLAND RAILRD' 'NYS DEPT TAX AND FINANCE']
# BORO_NM : ['BROOKLYN' 'QUEENS' 'MANHATTAN' 'BRONX' 'STATEN ISLAND']
# ADDR_PCT_CD : [ 78.  84. 106.  19. 115.  46. 122.  61.  25. 120.  33.  40.  48. 107.
#   83.  49. 113.  67. 102.   7.  75. 108.  45.  88.   1.  90.  72.  81.
#   77.  52.  18.   9.  32.  14.   5.  60. 105.  47.  73.  44.  62. 104.
#  114. 112.  79. 110.   6.  26. 103.  24.  23. 111.  28. 101. 121.  13.
#   70.  43.  41. 109.  76.  63.  42.  69.  68.  66.  30. 100.  20.  71.
#   34.  17.  22. 123.  94.  10.  50.  nan]
# LOC_OF_OCCUR_DESC : ['INSIDE' nan 'FRONT OF' 'REAR OF' 'OPPOSITE OF' 'OUTSIDE']
# PREM_TYP_DESC : ['RESIDENCE - APT. HOUSE' 'BUS (NYC TRANSIT)' 'COMMERCIAL BUILDING'
#  'DEPARTMENT STORE' 'STREET' 'RESIDENCE-HOUSE' 'HIGHWAY/PARKWAY'
#  'TRANSIT - NYC SUBWAY' 'RESIDENCE - PUBLIC HOUSING' 'LIQUOR STORE'
#  'GROCERY/BODEGA' 'OTHER' 'BAR/NIGHT CLUB' 'FOOD SUPERMARKET'
#  'CLOTHING/BOUTIQUE' 'FAST FOOD' 'PUBLIC SCHOOL' 'RESTAURANT/DINER'
#  'PARKING LOT/GARAGE (PRIVATE)' 'CHAIN STORE' 'TELECOMM. STORE' nan
#  'SMALL MERCHANT' 'DRUG STORE' 'PARKING LOT/GARAGE (PUBLIC)' 'HOTEL/MOTEL'
#  'AIRPORT TERMINAL' 'TAXI (YELLOW LICENSED)' 'PARK/PLAYGROUND' 'BUS STOP'
#  'PUBLIC BUILDING' 'DOCTOR/DENTIST OFFICE' 'STORE UNCLASSIFIED' 'CEMETERY'
#  'BANK' 'ATM' 'TRANSIT FACILITY (OTHER)' 'BEAUTY & NAIL SALON'
#  'STORAGE FACILITY' 'BUS TERMINAL' 'CHECK CASHING BUSINESS' 'HOSPITAL'
#  'GYM/FITNESS FACILITY' 'MARINA/PIER' 'CANDY STORE' 'SHOE'
#  'DRY CLEANER/LAUNDRY' 'BRIDGE' 'TAXI (LIVERY LICENSED)'
#  'FACTORY/WAREHOUSE' 'CHURCH' 'ABANDONED BUILDING' 'GAS STATION'
#  'BOOK/CARD' 'JEWELRY' 'OPEN AREAS (OPEN LOTS)' 'PRIVATE/PAROCHIAL SCHOOL'
#  'CONSTRUCTION SITE' 'VARIETY STORE' 'SOCIAL CLUB/POLICY'
#  'FERRY/FERRY TERMINAL' 'TAXI/LIVERY (UNLICENSED)' 'BUS (OTHER)' 'TUNNEL'
#  'PHOTO/COPY' 'VIDEO STORE' 'MOSQUE' 'SYNAGOGUE' 'LOAN COMPANY'
#  'OTHER HOUSE OF WORSHIP' 'TRAMWAY']
# PARKS_NM : [nan 'PROSPECT PARK' 'CENTRAL PARK' 'RAINEY PARK BRONX'
#  'FLUSHING MEADOWS CORONA PARK' 'BAILEY PLAYGROUND' 'MOUNT PROSPECT PARK'
#  'CITY LINE PARK' 'UNION SQUARE PARK' 'ZIMMERMAN PLAYGROUND'
#  "ST. MARY'S PARK BRONX" 'SARA D. ROOSEVELT PARK'
#  'JOSEPH RODMAN DRAKE PARK' 'RORY STAUNTON FIELD' 'EAST RIVER PARK'
#  'CONEY ISLAND BEACH & BOARDWALK' 'MARCUS GARVEY PARK' 'PLAYGROUND 52 LII'
#  'FORT GREENE PARK' 'MOORE HOMESTEAD PLAYGROUND'
#  'SPERANDEO BROTHERS PLAYGROUND' 'MADISON SQUARE PARK'
#  'COLUMBUS PARK AT MANHATTAN' 'HAMILTON METZ FIELD' 'LUNA PARK'
#  "DANIEL M. O'CONNELL PLAYGROUND" 'CROTONA PARK'
#  "POOR RICHARD'S PLAYGROUND" 'DAWSON PLAYGROUND' 'MARINE PARK'
#  'BELMONT PLAYGROUND BRONX' 'BUFANO PARK' 'BELT PARKWAY/SHORE PARKWAY'
#  'MULLALY PARK' 'MCLAUGHLIN PARK' 'HIGHBRIDGE PARK BRONX SIDE'
#  'WASHINGTON SQUARE PARK' 'EQUITY PARK' 'CLOVE LAKES PARK'
#  'BRIDGE PARK BROOKLYN' 'JACKIE ROBINSON PARK MANHATTAN'
#  'NORTHERN PLAYGROUND' 'FRED SAMUEL PLAYGROUND' 'ARCILLA PLAYGROUND'
#  'CLAREMONT PARK' 'AQUEDUCT WALK' 'BROADWAY MALLS'
#  'CAPTAIN RIVERA PLAYGROUND' 'MERRIAM PLAYGROUND' 'DYKER BEACH PARK'
#  'WILLIAMSBRIDGE OVAL' 'MACOMBS DAM PARK' 'RIVERSIDE PARK'
#  'KISSENA CORRIDOR PARK' 'JOYCE KILMER PARK' 'FORT TRYON PARK'
#  'SUNSET PARK' 'BRONX RIVER PARKWAY' 'RUFUS KING PARK'
#  'J. HOOD WRIGHT PARK' 'DR. CHARLES R. DREW PARK'
#  'ROCKAWAY BEACH AND BOARDWALK' 'INWOOD PARK' 'LINDSAY TRIANGLE'
#  'SHORE PARK AND PARKWAY' 'PARK OF THE AMERICAS' 'BRIDGE PARK 3'
#  'ROCHDALE PARK' 'RAMON APONTE PARK' 'PELHAM BAY PARK'
#  'FRANCIS LEWIS PARK' 'FRIENDS FIELD' 'HUNTS POINT PLAYGROUND'
#  'LAURELTON PLAYGROUND' 'COLEMAN PLAYGROUND' "PEOPLE'S PARK"
#  'INWOOD HILL PARK' 'THOMAS JEFFERSON PARK' 'HARLEM RIVER PARK'
#  'JUNIPER VALLEY PARK' 'PETROSINO SQUARE' 'BRONX PARK'
#  'MARIA HERNANDEZ PARK' 'DETECTIVE JOSEPH MAYROSE PARK'
#  'RODNEY PLAYGROUND NORTH' 'MARTIN LUTHER KING JR. PLAYGROUND'
#  'RIVER AVENUE PARKS' 'CARROLL PARK' 'GOBLE PLAYGROUND'
#  'RICHMAN (ECHO) PARK' 'MCDONALD PLAYGROUND BROOKLYN' 'VAN CORTLANDT PARK'
#  'DREW PLAYGROUND' 'COMMODORE BARRY PARK' 'CASTLE HILL PLAYGROUND'
#  "OWL'S HEAD PARK" 'COL. YOUNG PLAYGROUND' 'ELTON PLAYGROUND'
#  'TREMONT PARK' 'MAPLE PLAYGROUND'
#  'LINCOLN TERRACE / ARTHUR S. SOMERS PARK'
#  'HIGHBRIDGE PARK MANHATTAN SIDE' 'CONEY ISLAND CREEK PARK'
#  'JAMES J WALKER PARK' 'MARCONI PARK' 'MCCARREN PARK' 'BATTERY PARK'
#  'ALLEY POND PARK' 'HOWARD PLAYGROUND' 'NEIGHBORS OF VEGA BAJA'
#  'KELLY PARK' 'HAPPY WARRIOR PLAYGROUND' 'BROWER PARK'
#  'UNNAMED PARK ON BEACH CHANNEL DRIVE & BEACH 89TH TO OLD BEACH 88TH STREET'
#  'JACOB JOFFE FIELDS' 'WATSON GLEASON PLAYGROUND' 'FORT WASHINGTON PARK'
#  "RANDALL'S ISLAND PARK" 'SPACE TIME PLAYGROUND'
#  'FREDERICK B. JUDGE PLAYGROUND' 'ASTORIA PARK'
#  "ST. JOHN'S RECREATION CENTER" 'BROOKLYN BRIDGE PARK'
#  'GROVER CLEVELAND PLAYGROUND' 'BATTERY PARK CITY'
#  'FOX PLAYGROUND BROOKLYN' 'TOMPKINS SQUARE PARK'
#  'LOUIS ARMSTRONG PLAYGROUND' 'SETH LOW PLAYGROUND/ BEALIN SQUARE'
#  'FRANZ SIGEL PARK' 'ATHENS SQUARE' 'HERBERT VON KING PARK'
#  'CALLAHAN-KELLY PLAYGROUND' 'PUGSLEY CREEK PARK' 'LINDEN PARK'
#  'WEST PLAYGROUND' 'THE OLDE TOWNE OF FLUSHING BURIAL GROUND'
#  'CYPRESS HILLS PLAYGROUND' 'MARION HOPKINSON PLAYGROUND'
#  'CARMANSVILLE PLAYGROUND' 'PARADE GROUND' 'JAMAICA PLAYGROUND'
#  'PERETZ SQUARE' 'QUEENSBRIDGE PARK' 'JOHN HANCOCK PLAYGROUND'
#  'MORRIS MESA' 'CALVERT VAUX PARK' 'FREDERICK DOUGLASS PLAYGROUND'
#  'SEWARD PARK' 'AMERSFORT PARK' 'ST. JAMES PARK'
#  'VETERANS PARK STATEN ISLAND' 'HARLEM ART PARK' 'WALTON PARK'
#  'HARVARD PLAYGROUND' 'DONGAN PLAYGROUND' 'ROY WILKINS RECREATION CENTER'
#  'STERNBERG PARK' 'MCKINLEY PARK' 'GORMAN PARK' 'MORNINGSIDE PARK'
#  'DE HOSTOS PLAYGROUND' 'WHALEN PARK' 'GREAT KILLS PARK' 'TRAVERS PARK'
#  'CAMBRIA PLAYGROUND' 'RAINEY PARK QUEENS' 'EPIPHANY PLAYGROUND'
#  'CHESTER PLAYGROUND' 'CAPTAIN TILLY PARK' 'SLATTERY PLAYGROUND'
#  "MARC AND JASON'S PLAYGROUND" 'RED HOOK RECREATION AREA' 'DEVOE PARK'
#  'SARATOGA PARK' 'WINGATE PARK' 'MATTHEWS - PALMER PLAYGROUND'
#  'UNNAMED PARK ON BRUCKNER EXPRESSWAY WEST OF MORRISON AVENUE'
#  'DUNBAR PLAYGROUND' 'LT. JOSEPH PETROSINO PARK' 'ST. ALBANS PARK'
#  'IRVING SQUARE PARK' 'CONCRETE PLANT PARK'
#  'UNNAMED PARK ON SUMMIT AVENUE' 'PARKSIDE PLAYGROUND BROOKLYN'
#  'EVERGREEN PARK' 'STROUD PLAYGROUND'
#  'FRANKLIN D. ROOSEVELT BOARDWALK AND BEACH' 'NOBLE PLAYGROUND'
#  'ST. NICHOLAS PARK' 'CHELSEA PARK' 'HARDING PARK' 'EDMONDS PLAYGROUND'
#  'BLAND PLAYGROUND' 'DECATUR PLAYGROUND'
#  'MCDONALD PLAYGROUND STATEN ISLAND' 'ELMHURST PARK'
#  'BROOKLYN BOTANIC GARDEN' 'RECREATIONAL AREA' 'FOREST PARK'
#  'ALLEN MALL ONE' 'STUYVESANT SQUARE' 'UNNAMED PARK ON FETHERBED LANE'
#  'GARDEN PLAYGROUND' 'POWELL PLAYGROUND' 'ECHO TRIANGLE'
#  'TOTTENVILLE POOL' 'FERRY POINT PARK' 'EAST ELMHURST PLAYGROUND'
#  'FRANK PRINCIPE PARK' 'PETER MINUIT PLAYGROUND' 'COFFEY PARK'
#  'BUSHWICK PLAYGROUND ON KNICKERBOCKER AVENUE' 'DOME PLAYGROUND'
#  'STOCKTON PLAYGROUND' 'HARRIS PARK' "ST. MICHAEL'S PARK"
#  'HOWARD VON DOHLEN PLAYGROUND' 'HOFFMAN PARK'
#  'EAST RIVER ESPLANADE E 90TH ST TO E 125TH ST'
#  'JACOB H. SCHIFF PLAYGROUND' 'CORONA GOLF PLAYGROUND' 'HIGHLAND PARK'
#  "ST. ANDREW'S PLAYGROUND" 'BOWNE PARK' 'JEROME SLOPE'
#  'KOLBERT PLAYGROUND' 'MAURICE A FITZGERALD PLAYGROUND' 'ALBEN TRIANGLE'
#  'EWEN PARK' 'ETHAN ALLEN PLAYGROUND' 'PAERDEGAT PARK'
#  'BROWNSVILLE PLAYGROUND' 'TUDOR PARK' 'CPL. THOMPSON PARK'
#  'GEORGE WALKER JR. PARK' 'BRYANT PARK' 'CITY HALL PARK' 'GRAVESEND PARK'
#  'WASHINGTON PARK BRONX' 'LEFFERTS PLAYGROUND' 'SURF PLAYGROUND'
#  'BAISLEY POND PARK' 'MOSHOLU PARKWAY' 'UNIVERSITY WOODS'
#  'PENN SOUTH PLAYGROUND' 'KOSCIUSZKO POOL' 'BUSHWICK INLET PARK'
#  'RAINBOW PLAYGROUND' 'HORSESHOE PLAYGROUND' 'MCCAFFREY PLAYGROUND'
#  'STEBBINS PLAYGROUND' 'WALD PLAYGROUND' 'OGDEN PLIMPTON PLAYGROUND'
#  'SETON FALLS PARK' 'MANHATTAN BEACH PARK' 'LONDON PLANETREE PLAYGROUND'
#  'UNNAMED PARK ON RIVERSIDE DRIVE' 'JOSEPH AUSTIN PLAYGROUND'
#  'DEVANNEY TRIANGLE' 'VAN ALST PLAYGROUND' "WASHINGTON'S WALK"
#  'LT. LIA PLAYGROUND' 'ASTORIA HEIGHTS PLAYGROUND' 'CATHERINE SLIP MALLS'
#  'PETERS FIELD' 'DETECTIVE KEITH L WILLIAMS PARK' 'OCEAN BREEZE PARK'
#  'COLONEL CHARLES YOUNG TRIANGLE' 'BOOKER T. WASHINGTON PLAYGROUND'
#  'MAGENTA PLAYGROUND' 'MILL POND PARK' 'SIMEONE PARK' 'GALILEO PLAYGROUND'
#  'EAST RIVER WATERFRONT ESPLANADE' 'WASHINGTON HALL PARK'
#  'CHIEF DENNIS L. DEVLIN PARK' 'AMERICAN TRIANGLE'
#  'TRIANGLE AT E175TH STREET' 'BROOKVILLE PARK' 'BEHAGEN PLAYGROUND'
#  'P.S. 155 PLAYGROUND' 'UNIVERSITY MALLS' 'DUTCH KILLS PLAYGROUND'
#  'JACKIE ROBINSON PLAYGROUND' 'ISHAM PARK' 'EAST RIVER PLAYGROUND'
#  'NICHOLAS NAQUAN HEYWARD JR. PARK' 'STANLEY ISAACS PLAYGROUND'
#  'SOL BLOOM PLAYGROUND' 'CASTLE HILL PARK' 'ORACLE PLAYGROUND'
#  'MONSIGNOR KETT PLAYGROUND' 'MOSHOLU PLAYGROUND' 'BETSY HEAD PARK'
#  'BARRETTO POINT PARK' 'DUKE PARK' 'TILDEN PLAYGROUND'
#  'PAERDEGAT BASIN PARK' 'DITMARS PARK' 'WEST 4TH STREET COURTS'
#  'SOUNDVIEW PARK' 'HOWARD BENNETT PLAYGROUND' 'CHELSEA RECREATION CENTER'
#  'AGNES HAYWOOD PLAYGROUND' 'TONY DAPOLITO RECREATION CENTER'
#  'CAPTAIN DERMODY TRIANGLE' 'KISSENA PARK'
#  'UNNAMED PARK ON CROSS BRONX EXPRESSWAY & FEATHERBED LANE'
#  'BRIARWOOD PLAYGROUND' 'CROWLEY PLAYGROUND' 'JOHN JAY PARK'
#  'ZION TRIANGLE' 'RAOUL WALLENBERG FOREST' 'HOUSTON PLAYGROUND'
#  'MARIE CURIE PARK' 'STARLIGHT PARK' 'GIVANS CREEK WOODS'
#  'HAVEMEYER PLAYGROUND' 'TOMPKINSVILLE PARK' 'LORETO PLAYGROUND'
#  'ANNADALE PLAYGROUND' 'BRADHURST URBAN RENEWAL PARK' 'REMSEN PLAYGROUND'
#  'COURTNEY CALLENDER PLAYGROUND' 'TWENTY-FOUR SYCAMORES PARK'
#  'THE CYCLONE' 'DEAN PLAYGROUND' 'GRAND ARMY PLAZA BROOKLYN'
#  'LINCOLN RD BLOCK ASSOCIATION' 'GRANT PARK' 'WOODRUFF PLAYGROUND'
#  'ST. NICHOLAS PLAYGROUND NORTH' 'P.O. REINALDO SALGADO PLAYGROUND'
#  'LINWOOD PLAYGROUND' 'STAR SPANGLED PLAYGROUND' 'J.J. BYRNE PLAYGROUND'
#  'MIDDLETON PLAYGROUND' 'CLINTONVILLE PLAYGROUND' 'CURTIS PLAYGROUND'
#  'BARRETTO PARK' 'HOYT PLAYGROUND' 'GERTRUDE EDERLE RECREATION CENTER'
#  'BILDERSEE PLAYGROUND' 'PLIMPTON PLAYGROUND' 'TEPPER TRIANGLE'
#  'CASERTA PLAYGROUND' 'DOWNING STREET PLAYGROUND' 'BEACH 9 PLAYGROUND'
#  "ST. MICHAEL'S PLAYGROUND" 'MILESTONE PARK' 'ALLEY PARK'
#  'ALICE KORNEGAY TRIANGLE' 'MOTT PLAYGROUND' 'BOWNE PLAYGROUND'
#  'SHERMAN CREEK' 'NEPTUNE PLAYGROUND' 'HINTON PARK' 'VERDI SQUARE'
#  'MARLBORO PLAYGROUND' 'ROBERT E. VENABLE PARK'
#  'AMERICAN VETERANS MEMORIAL PIER' 'SETON PARK' 'PULASKI PLAYGROUND'
#  'BENNETT PARK' 'BROOKLYN HEIGHTS PROMENADE'
#  'CLASSON PLAYGROUND AT CLASSON AVENUE & LAFAYETTE AVENUE'
#  'PLAYGROUND 174' 'CONTINENTAL ARMY PLAZA' 'WALTER WARD PLAYGROUND'
#  'FATHER DUFFY SQUARE' 'QUARRY BALLFIELDS' 'REDFERN PLAYGROUND'
#  'REAL GOOD PARK' 'PELHAM PARKWAY' 'LEIF ERICSON PARK' 'SUMNER PLAYGROUND'
#  'FAIRMOUNT PLAYGROUND' 'FORDHAM LANDING PLAYGROUND'
#  "VAN CORTLANDT'S TAIL" 'SAW MILL PLAYGROUND' 'CUNNINGHAM PARK'
#  'BENSONHURST PARK' 'HAFFEN PARK' 'POE PARK'
#  'UNNAMED PARK ON E 120TH STREET' 'HIGH ROCK PARK' 'FLYNN PLAYGROUND'
#  'SAMUEL N. BENNERSON 2ND PLAYGROUND' 'ALMEDA PLAYGROUND'
#  'UNNAMED PARK ON 43RD AVENUE' 'MAJOR MARK PARK' 'METRO TRIANGLE'
#  'MORRIS GARDEN' 'CHERRY TREE PARK' 'VIDALIA PARK' 'HAVEN AVENUE'
#  'SPRINGFIELD PARK' "MURPHY'S BROTHER'S PLAYGROUND" 'TORSNEY PLAYGROUND'
#  'HERALD SQUARE' 'STARS & STRIPES PLAYGROUND' 'RAILROAD PARK BRONX'
#  'DODGER PLAYGROUND' 'NOSTRAND PLAYGROUND' 'A PHILIP RANDOLPH SQUARE'
#  'NATHAN STRAUS PLAYGROUND' "HELL'S KITCHEN PARK" 'SOUTH BEACH WETLANDS'
#  'MOORE PLAYGROUND' 'TIFFANY PLAYGROUND' 'TANAHEY PLAYGROUND'
#  'BEACH CHANNEL PLAYGROUND' 'ADAM CLAYTON POWELL JR. MALLS'
#  'NORTH 5TH STREET PIER AND PARK' 'LAGUARDIA LANDING LIGHTS'
#  'UNNAMED PARK ON CROSS BRONX EXPRESSWAY & ARTHUR AVENUE TO BELMONT AVENUE'
#  'DOUGHBOY PLAZA' 'RAYMOND BUSH PLAYGROUND' "SEAN'S PLACE"
#  "PRINTER'S PARK" 'POTOMAC PLAYGROUND' 'KAISER PARK' 'SEDGWICK PLAYGROUND'
#  'FULTON PARK' 'PLAYGROUND ONE FORTY' 'BENNINGER PLAYGROUND'
#  'STAPLETON PLAYGROUND' 'BELMONT PLAYGROUND BROOKLYN'
#  'ALEXANDER HAMILTON PLAYGROUND' 'BUSHWICK PLAYGROUND ON FLUSHING AVENUE'
#  'CRACK IS WACK PLAYGROUND' 'MAHONEY PLAYGROUND' 'JAIME CAMPIZ PLAYGROUND'
#  'GUN HILL PLAYGROUND' 'FORT HAMILTON ATHLETIC FIELD'
#  'EL JARDIN DEL PARAISO PARK' 'BATH BEACH PARK' 'AMPERE PLAYGROUND'
#  'UNDERHILL PLAYGROUND' 'TAAFFE PLAYGROUND' 'ASSER LEVY PLAYGROUND'
#  'BEANSTALK PLAYGROUND' 'COOPER PARK' 'ASPHALT GREEN' 'PINK PLAYGROUND'
#  'SCHENCK PLAYGROUND' 'STRIPPOLI SQUARE' 'COBBLE HILL PARK'
#  'WILLIS PLAYGROUND' 'FISH PLAYGROUND' 'BURNS PLAYGROUND'
#  'CHERRY CLINTON PLAYGROUND' 'RANAQUA PARK' 'THOMAS GREENE PLAYGROUND'
#  'UNNAMED PARK ON NELSON AVENUE' 'SCARANGELLA PARK' 'CHRISTOPHER PARK'
#  'DR. RONALD MCNAIR PARK' 'DR. GERTRUDE B. KELLY PLAYGROUND'
#  'ROCKAWAY FREEWAY' 'CANARSIE PARK' 'MSGR. MCGOLRICK PARK'
#  'POPPENHUSEN PARK' 'RUSSELL PEDERSEN PLAYGROUND' 'HOMECREST PLAYGROUND'
#  'ENNIS PLAYGROUND' 'CROTONA PARKWAY MALLS' 'WARDS ISLAND PARK'
#  'HALLETS COVE PLAYGROUND' 'CLARK PLAYGROUND' 'MIDLAND PLAYGROUND'
#  "D'AURIA-MURPHY TRIANGLE" 'WAGNER HOUSES POOL'
#  'HART PLAYGROUND ON BROADWAY' 'NEPONSIT MALL'
#  'JUDGE MOSES WEINSTEIN PLAYGROUND' 'MURRAY PLAYGROUND'
#  'RODNEY PLAYGROUND SOUTH' 'FOX PLAYGROUND BRONX'
#  'ALBERT J. PARHAM PLAYGROUND' 'P.O. SERRANO PLAYGROUND'
#  'BILL BROWN PLAYGROUND' 'SHELTERING ARMS PLAYGROUND' 'WINFIELD PLAZA'
#  'SCHIFF MALL' 'PLAYGROUND NINETY' 'DE WITT CLINTON PARK'
#  'FABER POOL AND PARK' 'EASTERN PARKWAY' 'WAKEFIELD PLAYGROUND'
#  'THURSBY BASIN PARK' 'BARUCH PLAYGROUND' 'LITTLE BAY PARK'
#  'JEROME PLAYGROUND' 'TAPPEN PARK' "HUNTER'S POINT SOUTH PARK"
#  'VLADECK PARK' 'MOUNT HOPE PLAYGROUND' 'PAUL RAIMONDA PLAYGROUND'
#  'RENAISSANCE PLAYGROUND' 'CARVER PLAYGROUND' 'VAN DYKE PLAYGROUND'
#  'ABRAHAM LINCOLN PLAYGROUND' 'PARK SLOPE PLAYGROUND' 'HAMILTON FISH PARK'
#  'GRADY PLAYGROUND' 'OSBORN PLAYGROUND' 'LA GUARDIA PLAYGROUND'
#  'THE HIGH LINE' 'BAYVIEW PLAYGROUND' 'TEN EYCK PLAYGROUND'
#  'BERGEN BEACH PLAYGROUND' 'UNNAMED PARK ON GRAND AVENUE'
#  'CADMAN PLAZA PARK' 'GREELEY SQUARE PARK'
#  'POLICE OFFICER NICHOLAS DEMUTIIS PARK' 'PLANEVIEW PARK'
#  'ALFRED E. SMITH PLAYGROUND' 'STEINWAY PLAYGROUND' 'STARR PLAYGROUND'
#  'JOHN J CARTY PARK' 'GRAND CENTRAL PARKWAY' 'HOOVER - MANTON PLAYGROUNDS'
#  'LOZADA PLAYGROUND' 'FORT TOTTEN PARK' '5TH ST SLOPE GARDEN'
#  'DETECTIVE WILLIAM T. GUNN PARK'
#  'UNNAMED PARK ON THE SOUTHSIDE OF E 175TH STREET' 'JUNCTION PLAYGROUND'
#  'ST. LAWRENCE TRIANGLE' 'ROCK GARDEN PARK' 'SAMUEL SEABURY PLAYGROUND'
#  'LYONS POOL' 'MCKINLEY SQUARE' 'PLAYGROUND ONE THIRTY FOUR CXXXIV'
#  'VLEIGH PLAYGROUND' 'THE PEARLY GATES' 'SUNSHINE PLAYGROUND'
#  'BATHGATE PLAYGROUND' 'GARIBALDI PLAYGROUND' 'VESUVIO PLAYGROUND'
#  'SEASIDE PLAYGROUND' 'RECREATION CENTER 54' 'CONFERENCE HOUSE PARK'
#  'ADMIRAL FARRAGUT PLAYGROUND' 'NEHEMIAH PARK' 'BOWLING GREEN'
#  'LINDOWER PARK' 'ASSER LEVY PARK' 'MARCY PLAYGROUND' 'RIENZI PLAYGROUND'
#  'CARL SCHURZ PARK' 'FREDERICK JOHNSON PLAYGROUND' 'PLEASANT PARK GARDEN'
#  'DE COLORES COMMUNITY YARD AND CULTURAL CENTER' 'PONTIAC PLAYGROUND'
#  'HOLCOMBE RUCKER PARK' 'TEN EYCK PLAZA' 'EAGLE SLOPE'
#  'NEWPORT PLAYGROUND' "THE PAINTER'S PLAYGROUND"
#  'JACKIE ROBINSON COMMUNITY GARDEN' 'FIRST PARK'
#  'JAMES WELDON JOHNSON PLAYGROUND' 'GORMAN PLAYGROUND'
#  'UNNAMED PARK ON PROSPECT EXPRESSWAY BETWEEN 3RD AVENUE & 7TH AVENUE'
#  'IDLEWILD PARK' '"UNCLE" VITO E. MARANZANO GLENDALE PLAYGROUND'
#  'GRACE PLAYGROUND' 'BROOKLYN MUSEUM' 'AMERICAN PLAYGROUND'
#  'ALLERTON PLAYGROUND' 'FERMI PLAYGROUND' 'SPIRIT PLAYGROUND'
#  'PENA HERRERA PARK' 'BREUKELEN BALLFIELDS' 'BARTLETT PLAYGROUND'
#  'MADISON COMMUNITY GREENTHUMB' 'BARTEL-PRITCHARD SQUARE'
#  'JESSE OWENS PLAYGROUND' 'FLUSHING FIELDS' 'LOTT PARK' 'SIREN SLOPE'
#  'UNNAMED PARK ON BELT PARKWAY' 'KELTCH PARK' 'PATTERSON PLAYGROUND'
#  'MURRAY HILL PLAYGROUND' 'LUTHER GULICK PLAYGROUND'
#  'CRISPUS ATTUCKS PLAYGROUND' 'MARTIN LUTHER KING PLAYGROUND'
#  'MACLAUGHLIN PLAYGROUND' 'DR. RONALD E. MCNAIR PLAYGROUND'
#  'WESTERLEIGH PARK' 'ROBERTO CLEMENTE BALLFIELD' 'STORY PLAYGROUND'
#  'UNNAMED PARK ON WEST MOUNT EDEN AVENUE' 'WASHINGTON PARK BROOKLYN'
#  'GARDEN AT MOORSE STREET' 'SHEEPSHEAD PLAYGROUND'
#  'EASTCHESTER PLAYGROUND' 'RALPH DEMARCO PARK' 'HALF-NELSON PLAYGROUND'
#  'ESTELLA DIGGS PARK' 'UNNAMED PARK ON E 102ND STREET'
#  "FRANK D. O'CONNOR PLAYGROUND" 'P.S. 149 ARTSY BLOOM COMMUNITY GARDEN'
#  'CHALLENGE PLAYGROUND' 'HAGGERTY PARK' 'ROEBLING PLAYGROUND'
#  'CENTREVILLE PLAYGROUND' 'COLGATE CLOSE' 'ROSE HILL PARK'
#  'MERCER PLAYGROUND' 'LOPEZ PLAYGROUND' "ST. CATHERINE'S PARK"
#  "D'EMIC PLAYGROUND" 'VON BRIESEN PARK' 'FRANK GOLDEN PARK'
#  'DI GILIO PLAYGROUND' 'BANNEKER PLAYGROUND' 'SOUTH PACIFIC PLAYGROUND'
#  'PHIL "SCOOTER" RIZZUTO PARK' 'OLD TOWN PLAYGROUND' 'HINES PARK'
#  'BAYSWATER PARK' 'POSEIDON PLAYGROUND' 'CEDAR PLAYGROUND'
#  'EHRENREICH-AUSTIN PLAYGROUND' 'RAILROAD PLAYGROUND' 'EAST RIVER WALK'
#  'TAYLOR PLAYGROUND' 'BRIGHTON PLAYGROUND'
#  'SHERIDAN SQUARE VIEWING GARDEN' 'BOERUM PARK'
#  'SARATOGA SQUARE URBAN RENEWAL AREA, SITE 164' 'MELLETT PLAYGROUND'
#  'GOUVERNEUR PLAYGROUND' 'ARVERNE PLAYGROUND' 'PLAUT TRIANGLE'
#  'BEACH 30TH STREET PLAYGROUND' 'HENRY HUDSON PARK'
#  'LYONS SQUARE PLAYGROUND' 'PUBLIC PLACE' 'SOUTH ROCHDALE PLAYGROUND'
#  'BEATTY PLAZA' 'QUEENS VILLAGE VETERANS PLAZA' 'CORONA MAC PARK'
#  'NEWTOWN PLAYGROUND' 'SIXTEEN SYCAMORES PLAYGROUND' 'BIG BUSH PARK'
#  'UNNAMED PARK ON 51ST ROAD' 'SPUYTEN DUYVIL PLAYGROUND' 'YAK PLAYGROUND'
#  'WILLOWBROOK PARK' 'MACNEIL PARK' 'FOUNTAIN OF YOUTH PLAYGROUND'
#  'MOUNT HOPE GARDEN' 'MARBLE HILL PLAYGROUND']
# HADEVELOPT : [nan 'WILLIAMSBURG' 'MITCHEL' 'CONEY ISLAND' 'SUMNER'
#  'BUSHWICK II (GROUPS A & C)' 'MONROE' '303 VERNON AVENUE' 'STAPLETON'
#  'BROWNSVILLE' 'JOHNSON' 'PINK' 'RED HOOK EAST' 'SHEEPSHEAD BAY'
#  'BOULEVARD' 'BRONXDALE' 'DOUGLASS' 'THROGGS NECK ADDITION'
#  'SAMUEL (CITY)' 'BEDFORD-STUYVESANT REHAB' 'LOW HOUSES' 'WHITMAN'
#  'CYPRESS HILLS' 'ARMSTRONG II' 'POMONOK' 'EDENWALD' 'LINDEN'
#  'FORT INDEPENDENCE STREET-HEATH AVENUE' 'RANGEL' 'BARUCH' 'WOODSIDE'
#  'MCKINLEY' 'SEDGWICK' 'EAST 180TH STREET-MONTEREY AVENUE' 'RIIS'
#  'BETANCES I' 'GLEBE AVENUE-WESTCHESTER AVENUE' 'MARCY' 'INDEPENDENCE'
#  'CASTLE HILL' 'PENNSYLVANIA AVENUE-WORTMAN AVENUE'
#  'BAYSIDE-OCEAN BAY APTS' 'GRANT' 'STUYVESANT GARDENS I'
#  'MILL BROOK EXTENSION' 'LENOX ROAD-ROCKAWAY PARKWAY' 'REDFERN'
#  '1162-1176 WASHINGTON AVENUE' 'INGERSOLL' 'BORINQUEN PLAZA I' 'DYCKMAN'
#  'TAPSCOTT STREET REHAB' "MARINER'S HARBOR" 'WALD' 'ADAMS'
#  'WEST BRIGHTON I' 'LINCOLN' 'ALBANY' 'BUSHWICK' 'GOWANUS'
#  '572 WARREN STREET' 'TILDEN' 'AMSTERDAM' 'WEBSTER' 'HOPE GARDENS'
#  'VLADECK' 'FOREST' 'CLAREMONT PARKWAY-FRANKLIN AVENUE' 'MANHATTANVILLE'
#  'WAGNER' 'MORRIS I' 'VLADECK II' 'CARVER' '33-35 SARATOGA AVENUE'
#  'FARRAGUT' 'THROGGS NECK' 'JACKSON' 'HAMMEL' 'MARKHAM GARDENS'
#  'EASTCHESTER GARDENS' 'MORRIS II' 'PATTERSON' 'UNIVERSITY AVENUE REHAB'
#  'ASTORIA' 'ROOSEVELT II' '131 SAINT NICHOLAS AVENUE' 'VAN DYKE I'
#  "SAINT MARY'S PARK" 'PELHAM PARKWAY' 'SEWARD PARK EXTENSION'
#  'QUEENSBRIDGE SOUTH' 'PARKSIDE' 'CLASON POINT GARDENS' 'GLENWOOD'
#  'HOWARD' 'SMITH' 'COOPER PARK' 'LOWER EAST SIDE I INFILL'
#  'HIGHBRIDGE GARDENS' 'SOUNDVIEW' 'MORRIS HEIGHTS REHAB'
#  'LONGFELLOW AVENUE REHAB' 'RED HOOK WEST' 'EAST 173RD STREET-VYSE AVENUE'
#  'MILL BROOK' 'LEHMAN' 'ARMSTRONG I' 'TOMPKINS' 'MORRISANIA AIR RIGHTS 42'
#  'HIGHBRIDGE REHABS (ANDERSON AVENUE)' 'LATIMER GARDENS'
#  'SOUTHERN BOULEVARD' 'WYCKOFF GARDENS' '1471 WATSON AVENUE' 'SOUTH BEACH'
#  'MARBLE HILL' 'SACK WERN' 'BUTLER' 'CONEY ISLAND I (SITE 1B)'
#  'LONG ISLAND BAPTIST HOUSES' 'BELMONT-SUTTER AREA' 'CLINTON' 'LA GUARDIA'
#  'GRAVESEND' 'HOWARD AVENUE' 'RALPH AVENUE REHAB' 'KING TOWERS'
#  'BORINQUEN PLAZA II' 'CLAREMONT REHAB (GROUP 3)'
#  'UNITY PLAZA (SITES 4-27)' 'FIORENTINO PLAZA' 'MELROSE' 'NOSTRAND'
#  'BRONX RIVER' 'BERRY' 'SARATOGA SQUARE' 'BREVOORT' 'CARLETON MANOR'
#  'LAVANBURG HOMES' 'LAFAYETTE' 'MOORE' 'SUTTER AVENUE-UNION STREET'
#  'MARLBORO' 'TELLER AVENUE-EAST 166TH STREET' 'WEEKSVILLE GARDENS'
#  'ROOSEVELT I' 'BOSTON SECOR' 'AUDUBON' 'BAY VIEW'
#  'CLAREMONT REHAB (GROUP 4)' 'RUTGERS' 'CLAREMONT REHAB (GROUP 2)'
#  'REID APARTMENTS' 'BUSHWICK II (GROUPS B & D)' 'BOSTON ROAD PLAZA'
#  'HOWARD AVENUE-PARK PLACE' 'UNITY PLAZA (SITES 17,24,25A)'
#  'HUGHES APARTMENTS' 'RUTLAND TOWERS' 'UNION AVENUE-EAST 166TH STREET'
#  'MURPHY' '830 AMSTERDAM AVENUE' 'GUN HILL' 'SOUTH BRONX AREA (SITE 402)'
#  'MACOMBS ROAD' 'HARLEM RIVER' 'ALBANY II' 'MOTT HAVEN' 'WILLIAMS PLAZA'
#  'ATLANTIC TERMINAL SITE 4B' 'BAILEY AVENUE-WEST 193RD STREET' 'GOMPERS'
#  'RICHMOND TERRACE' 'STERLING PLACE REHAB (STERLING-BUFFALO)' 'RIIS II'
#  'HOE AVENUE-EAST 173RD STREET' 'UPACA (SITE 6)' 'HERNANDEZ' 'TAFT'
#  'UPACA (SITE 5)' 'MARCY AVENUE-GREENE AVENUE SITE A'
#  'STERLING PLACE REHAB (SAINT JOHNS-STERLING)' 'GARVEY (GROUP A)'
#  'BOYNTON AVENUE REHAB' 'FENIMORE-LEFFERTS'
#  'BRYANT AVENUE-EAST 174TH STREET' 'TWO BRIDGES URA (SITE 7)'
#  'CASSIDY-LAFAYETTE' 'BREUKELEN' 'TWIN PARKS WEST (SITE 1 & 2)' 'BLAND'
#  'QUEENSBRIDGE NORTH' 'BEACH 41ST STREET-BEACH CHANNEL DRIVE' 'HYLAN'
#  'DOUGLASS ADDITION' 'CAMPOS PLAZA I' 'VANDALIA AVENUE'
#  'BERRY STREET-SOUTH 9TH STREET' 'WEST FARMS ROAD REHAB' 'DAVIDSON'
#  'TODT HILL' 'MANHATTANVILLE REHAB (GROUP 2)' 'LEXINGTON'
#  'TWIN PARKS EAST (SITE 9)' 'UNION AVENUE-EAST 163RD STREET' 'MORRISANIA'
#  'WOODSON' 'TAYLOR STREET-WYTHE AVENUE' 'BUSHWICK II CDA (GROUP E)'
#  'BAISLEY PARK' 'PARK ROCK REHAB' 'STEBBINS AVENUE-HEWITT PLACE'
#  'BRONX RIVER ADDITION' 'PALMETTO GARDENS'
#  'WSUR (SITE C) 589 AMSTERDAM AVENUE' 'WEST TREMONT REHAB (GROUP 3)'
#  'WEST BRIGHTON II' 'VAN DYKE II' 'RANDALL AVENUE-BALCOM AVENUE'
#  'COLLEGE AVENUE-EAST 165TH STREET' 'FORT WASHINGTON AVENUE REHAB'
#  'BARUCH HOUSES ADDITION' 'FIRST HOUSES' 'CLAREMONT REHAB (GROUP 5)'
#  '45 ALLEN STREET' 'HIGHBRIDGE REHABS (NELSON AVENUE)' 'MILBANK-FRAWLEY'
#  'CROWN HEIGHTS' 'EAST 165TH STREET-BRYANT AVENUE'
#  'OCEAN HILL-BROWNSVILLE' "O'DWYER GARDENS"
#  'LOWER EAST SIDE REHAB (GROUP 5)' 'FRANKLIN AVENUE II CONVENTIONAL'
#  'WEST TREMONT REHAB (GROUP 2)' 'LA GUARDIA ADDITION'
#  'OCEANSIDE-OCEAN BAY APTS' 'GRAMPION' 'BETANCES III' 'KINGSBOROUGH 77'
#  'MARSHALL PLAZA' 'GLENMORE PLAZA' 'OCEAN HILL APARTMENTS'
#  'DE HOSTOS APARTMENTS' 'CAREY GARDENS'
#  'MARCY AVENUE-GREENE AVENUE SITE B' 'EAGLE AVENUE-EAST 163RD STREET'
#  'WEST TREMONT REHAB (GROUP 1)' 'EAST NEW YORK CITY LINE'
#  'BETHUNE GARDENS' 'LOWER EAST SIDE II' 'HARRISON AVENUE REHAB (GROUP B)'
#  'FRANKLIN AVENUE I CONVENTIONAL' 'WASHINGTON HEIGHTS REHAB PHASE III'
#  'FRANKLIN AVENUE II MHOP' 'PROSPECT PLAZA'
#  'HARRISON AVENUE REHAB (GROUP A)' 'WSUR (SITE B) 74 WEST 92ND STREET'
#  'JENNINGS STREET' 'FRANKLIN AVENUE III CONVENTIONAL'
#  'WEST TREMONT AVENUE-SEDGWICK AVENUE AREA' 'NEW LANE AREA'
#  'FRANKLIN AVENUE I MHOP' 'BETANCES VI' 'MIDDLETOWN PLAZA']
# X_COORD_CD : [ 986889.  986754. 1029051. ... 1012085. 1028127. 1038791.]
# Y_COORD_CD : [181967. 191591. 177326. ... 221026. 250827. 197431.]
# Latitude : [40.66614193 40.69255767 40.65329047 ... 40.77330605 40.85503628
#  40.70841937]
# Longitude : [-73.99048885 -73.9909719  -73.83854179 ... -73.89950531 -73.84139219
#  -73.8032769 ]
# Lat_Lon : ['(40.666141926, -73.990488846)' '(40.692557669, -73.990971896)'
#  '(40.65329047, -73.838541787)' ... '(40.773306053, -73.899505313)'
#  '(40.855036281, -73.841392191)' '(40.708419367, -73.803276898)']

# %%
# Print unique values in a certian column
print(df1['PREM_TYP_DESC'].unique())
print(len(df1['PREM_TYP_DESC'].unique()))
# Out:
# ['RESIDENCE - APT. HOUSE' 'BUS (NYC TRANSIT)' 'COMMERCIAL BUILDING'
#  'DEPARTMENT STORE' 'STREET' 'RESIDENCE-HOUSE' 'HIGHWAY/PARKWAY'
#  'TRANSIT - NYC SUBWAY' 'RESIDENCE - PUBLIC HOUSING' 'LIQUOR STORE'
#  'GROCERY/BODEGA' 'OTHER' 'BAR/NIGHT CLUB' 'FOOD SUPERMARKET'
#  'CLOTHING/BOUTIQUE' 'FAST FOOD' 'PUBLIC SCHOOL' 'RESTAURANT/DINER'
#  'PARKING LOT/GARAGE (PRIVATE)' 'CHAIN STORE' 'TELECOMM. STORE' nan
#  'SMALL MERCHANT' 'DRUG STORE' 'PARKING LOT/GARAGE (PUBLIC)' 'HOTEL/MOTEL'
#  'AIRPORT TERMINAL' 'TAXI (YELLOW LICENSED)' 'PARK/PLAYGROUND' 'BUS STOP'
#  'PUBLIC BUILDING' 'DOCTOR/DENTIST OFFICE' 'STORE UNCLASSIFIED' 'CEMETERY'
#  'BANK' 'ATM' 'TRANSIT FACILITY (OTHER)' 'BEAUTY & NAIL SALON'
#  'STORAGE FACILITY' 'BUS TERMINAL' 'CHECK CASHING BUSINESS' 'HOSPITAL'
#  'GYM/FITNESS FACILITY' 'MARINA/PIER' 'CANDY STORE' 'SHOE'
#  'DRY CLEANER/LAUNDRY' 'BRIDGE' 'TAXI (LIVERY LICENSED)'
#  'FACTORY/WAREHOUSE' 'CHURCH' 'ABANDONED BUILDING' 'GAS STATION'
#  'BOOK/CARD' 'JEWELRY' 'OPEN AREAS (OPEN LOTS)' 'PRIVATE/PAROCHIAL SCHOOL'
#  'CONSTRUCTION SITE' 'VARIETY STORE' 'SOCIAL CLUB/POLICY'
#  'FERRY/FERRY TERMINAL' 'TAXI/LIVERY (UNLICENSED)' 'BUS (OTHER)' 'TUNNEL'
#  'PHOTO/COPY' 'VIDEO STORE' 'MOSQUE' 'SYNAGOGUE' 'LOAN COMPANY'
#  'OTHER HOUSE OF WORSHIP' 'TRAMWAY']
# 71

# %%
df1
# Out:
#         CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM  \
# 46300    224807992   11/24/2015     16:00:00          NaN          NaN
# 571249   289768995   10/17/2014     17:00:00   10/17/2014     17:03:00
# 585411   533585687    10/7/2014     22:30:00    10/7/2014     22:38:00
# 834377   196907442    4/16/2014     18:10:00    4/16/2014     18:20:00
# 768712   471072107     3/1/2014     20:00:00          NaN          NaN
# ...            ...          ...          ...          ...          ...
# 993387   760913069   12/12/2013     21:16:00   12/12/2013     21:17:00
# 326471   690320245     5/6/2015      8:00:00     5/7/2015     17:30:00
# 601408   916467724    9/24/2014     10:00:00    9/27/2014     13:30:00
# 957908   548834543     1/2/2014     12:00:00    1/11/2014     10:00:00
# 487216   797990974     5/1/2014      0:01:00   12/23/2014     16:16:00
#
#             RPT_DT  KY_CD                       OFNS_DESC  PD_CD  \
# 46300   11/24/2015    112                     THEFT-FRAUD  739.0
# 571249  10/18/2014    341                   PETIT LARCENY  339.0
# 585411   10/8/2014    121  CRIMINAL MISCHIEF & RELATED OF  269.0
# 834377   4/16/2014    232   POSSESSION OF STOLEN PROPERTY  490.0
# 768712    6/3/2014    351  CRIMINAL MISCHIEF & RELATED OF  259.0
# ...            ...    ...                             ...    ...
# 993387  12/12/2013    341                   PETIT LARCENY  333.0
# 326471    5/7/2015    361   OFF. AGNST PUB ORD SENSBLTY &  639.0
# 601408   9/27/2014    107                        BURGLARY  224.0
# 957908   1/11/2014    340                          FRAUDS  718.0
# 487216  12/23/2014    104                            RAPE  157.0
#
#                                  PD_DESC  ... ADDR_PCT_CD LOC_OF_OCCUR_DESC  \
# 46300          FRAUD,UNCLASSIFIED-FELONY  ...        78.0            INSIDE
# 571249    LARCENY,PETIT FROM OPEN AREAS,  ...        84.0               NaN
# 585411    MISCHIEF,CRIMINAL,    UNCL 2ND  ...       106.0          FRONT OF
# 834377      STOLEN PROPERTY 3,POSSESSION  ...        19.0            INSIDE
# 768712  CRIMINAL MISCHIEF,UNCLASSIFIED 4  ...       115.0            INSIDE
# ...                                  ...  ...         ...               ...
# 993387    LARCENY,PETIT FROM STORE-SHOPL  ...        13.0            INSIDE
# 326471           AGGRAVATED HARASSMENT 2  ...        23.0          FRONT OF
# 601408    BURGLARY,RESIDENCE,UNKNOWN TIM  ...        69.0            INSIDE
# 957908    FRAUD,UNCLASSIFIED-MISDEMEANOR  ...        20.0            INSIDE
# 487216                            RAPE 1  ...        43.0            INSIDE
#
#                  PREM_TYP_DESC PARKS_NM  HADEVELOPT X_COORD_CD Y_COORD_CD  \
# 46300   RESIDENCE - APT. HOUSE      NaN         NaN   986889.0   181967.0
# 571249       BUS (NYC TRANSIT)      NaN         NaN   986754.0   191591.0
# 585411     COMMERCIAL BUILDING      NaN         NaN  1029051.0   177326.0
# 834377        DEPARTMENT STORE      NaN         NaN   996773.0   223149.0
# 768712  RESIDENCE - APT. HOUSE      NaN         NaN  1018714.0   214946.0
# ...                        ...      ...         ...        ...        ...
# 993387             CHAIN STORE      NaN         NaN   988619.0   209968.0
# 326471  RESIDENCE - APT. HOUSE      NaN         NaN   998829.0   226859.0
# 601408  RESIDENCE - APT. HOUSE      NaN         NaN  1011862.0   169726.0
# 957908  RESIDENCE - APT. HOUSE      NaN         NaN   990978.0   226359.0
# 487216  RESIDENCE - APT. HOUSE      NaN         NaN        NaN        NaN
#
#          Latitude  Longitude                        Lat_Lon
# 46300   40.666142 -73.990489  (40.666141926, -73.990488846)
# 571249  40.692558 -73.990972  (40.692557669, -73.990971896)
# 585411  40.653290 -73.838542   (40.65329047, -73.838541787)
# 834377  40.779168 -73.954784  (40.779168082, -73.954784146)
# 768712  40.756595 -73.875603  (40.756594678, -73.875603018)
# ...           ...        ...                            ...
# 993387  40.742997 -73.984235  (40.742997406, -73.984234687)
# 326471  40.789348 -73.947352  (40.789347893, -73.947352413)
# 601408  40.632500 -73.900521    (40.63250039, -73.90052077)
# 957908  40.787985 -73.975705   (40.78798499, -73.975705172)
# 487216        NaN        NaN                            NaN
#
# [500000 rows x 24 columns]

# %%
health = ['DRUG STORE','DOCTOR/DENTIST OFFICE','HOSPITAL']
residence = ['RESIDENCE-HOUSE','RESIDENCE - APT. HOUSE','RESIDENCE - PUBLIC HOUSING']
worship = ['CHURCH','SYNAGOGUE','OTHER HOUSE OF WORSHIP','MOSQUE']
pub = ['STREET','PUBLIC BUILDING','PARK/PLAYGROUND','PARKING LOT/GARAGE (PUBLIC)','PRIVATE/PAROCHIAL SCHOOL','BOOK/CARD','MARINA/PIER',
       'PUBLIC SCHOOL','CEMETERY']
retail = ['DRY CLEANER/LAUNDRY','GAS STATION','CHAIN STORE','BEAUTY & NAIL SALON',
          'COMMERCIAL BUILDING','HOTEL/MOTEL','SMALL MERCHANT','PARKING LOT/GARAGE (PRIVATE)',
          'DEPARTMENT STORE','GYM/FITNESS FACILITY','VARIETY STORE','CLOTHING/BOUTIQUE','TELECOMM. STORE',
          'JEWELRY','CANDY STORE','STORAGE FACILITY','VIDEO STORE']
Tranportation = ['TUNNEL','TRANSIT - NYC SUBWAY','BUS (NYC TRANSIT)','FERRY/FERRY TERMINAL','BUS STOP','TAXI (LIVERY LICENSED)',
                 'BRIDGE','AIRPORT TERMINAL','HIGHWAY/PARKWAY','BUS (OTHER)',
                 'TRANSIT FACILITY (OTHER)','BUS TERMINAL','TAXI (YELLOW LICENSED)','TAXI/LIVERY (UNLICENSED)','TRAMWAY']
Food_Beverage= ['BAR/NIGHT CLUB' , 'FAST FOOD' , 'RESTAURANT/DINER' , 'GROCERY/BODEGA' , 'FOOD SUPERMARKET' , 'SOCIAL CLUB/POLICY' , 'LIQUOR STORE']
finance = ['CHECK CASHING BUSINESS','BANK','ATM','LOAN COMPANY']
other = ['OTHER','STORE UNCLASSIFIED','CONSTRUCTION SITE','FACTORY/WAREHOUSE','OPEN AREAS (OPEN LOTS)','ABANDONED BUILDING','SHOE','PHOTO/COPY']

# %%
df1.head(4)
# Out:
#         CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM  \
# 46300    224807992   11/24/2015     16:00:00          NaN          NaN
# 571249   289768995   10/17/2014     17:00:00   10/17/2014     17:03:00
# 585411   533585687    10/7/2014     22:30:00    10/7/2014     22:38:00
# 834377   196907442    4/16/2014     18:10:00    4/16/2014     18:20:00
#
#             RPT_DT  KY_CD                       OFNS_DESC  PD_CD  \
# 46300   11/24/2015    112                     THEFT-FRAUD  739.0
# 571249  10/18/2014    341                   PETIT LARCENY  339.0
# 585411   10/8/2014    121  CRIMINAL MISCHIEF & RELATED OF  269.0
# 834377   4/16/2014    232   POSSESSION OF STOLEN PROPERTY  490.0
#
#                                PD_DESC  ... ADDR_PCT_CD LOC_OF_OCCUR_DESC  \
# 46300        FRAUD,UNCLASSIFIED-FELONY  ...        78.0            INSIDE
# 571249  LARCENY,PETIT FROM OPEN AREAS,  ...        84.0               NaN
# 585411  MISCHIEF,CRIMINAL,    UNCL 2ND  ...       106.0          FRONT OF
# 834377    STOLEN PROPERTY 3,POSSESSION  ...        19.0            INSIDE
#
#                  PREM_TYP_DESC PARKS_NM  HADEVELOPT X_COORD_CD Y_COORD_CD  \
# 46300   RESIDENCE - APT. HOUSE      NaN         NaN   986889.0   181967.0
# 571249       BUS (NYC TRANSIT)      NaN         NaN   986754.0   191591.0
# 585411     COMMERCIAL BUILDING      NaN         NaN  1029051.0   177326.0
# 834377        DEPARTMENT STORE      NaN         NaN   996773.0   223149.0
#
#          Latitude  Longitude                        Lat_Lon
# 46300   40.666142 -73.990489  (40.666141926, -73.990488846)
# 571249  40.692558 -73.990972  (40.692557669, -73.990971896)
# 585411  40.653290 -73.838542   (40.65329047, -73.838541787)
# 834377  40.779168 -73.954784  (40.779168082, -73.954784146)
#
# [4 rows x 24 columns]

# %%
# create function to loop once and create the categories
# scl 
def makeCategories(df):
  category = [health,residence,worship,pub,retail,Tranportation,Food_Beverage,finance,other]
  residence_count = 0
  health_count = 0
  worship_count = 0
  pub_count = 0
  retial_count = 0
  tranport_count = 0
  foodbev_count = 0
  finance_count = 0
  other_count = 0
  df['Food & beverage'] = 0

  for a in df['PREM_TYP_DESC']:
    if a in residence:      
      residence_count += 1
      
    if a in other:
      other_count += 1

    if a in finance:
      finance_count += 1

    if a in Food_Beverage:
      foodbev_count += 1
      df['Food and beverage'] = 1
      pass

    if a in Tranportation:
      tranport_count += 1

    if a in retail:
      retial_count += 1

    if a in worship:
      worship_count += 1
        
    if a in health:
      health_count += 1
      
  print('residence',residence_count)
  print('other',other_count)
  print('finance',finance_count)
  print('food',foodbev_count)        
  print('Transport',tranport_count)
  print('Retail',retial_count)
  print('Worship',worship_count)
  print('Health',health_count)

  return residence_count, other_count, finance_count, foodbev_count, tranport_count, retial_count, worship_count, health_count, pub_count

# %%
residencecount, othercount, financecount, foodbevcount, tranportcount, retialcount, worshipcount, healthcount, pubcount = makeCategories(df1)
# Out:
# residence 194140
# other 18490
# finance 3155
# food 26364
# Transport 19942
# Retail 55776
# Worship 1145
# Health 8171

# %%
#df1

# %%
df1.columns
# Out:
# Index(['CMPLNT_NUM', 'CMPLNT_FR_DT', 'CMPLNT_FR_TM', 'CMPLNT_TO_DT',
#        'CMPLNT_TO_TM', 'RPT_DT', 'KY_CD', 'OFNS_DESC', 'PD_CD', 'PD_DESC',
#        'CRM_ATPT_CPTD_CD', 'LAW_CAT_CD', 'JURIS_DESC', 'BORO_NM',
#        'ADDR_PCT_CD', 'LOC_OF_OCCUR_DESC', 'PREM_TYP_DESC', 'PARKS_NM',
#        'HADEVELOPT', 'X_COORD_CD', 'Y_COORD_CD', 'Latitude', 'Longitude',
#        'Lat_Lon', 'Food & beverage', 'Food and beverage'],
#       dtype='object')

# %%
#print(df1['PREM_TYP_DESC'].value_counts())
#df1.groupby(['PREM_TYP_DESC','BORO_NM']).count()
Felony_Type_Burow_DF = df1.groupby(['BORO_NM','PREM_TYP_DESC']).count()['LAW_CAT_CD']
Felony_Type_Burow_DF['BROOKLYN']
# Out:
# PREM_TYP_DESC
# ABANDONED BUILDING            66
# AIRPORT TERMINAL               2
# ATM                          140
# BANK                         445
# BAR/NIGHT CLUB              1069
#                             ...
# TRANSIT - NYC SUBWAY        2737
# TRANSIT FACILITY (OTHER)      79
# TUNNEL                        65
# VARIETY STORE                239
# VIDEO STORE                   21
# Name: LAW_CAT_CD, Length: 70, dtype: int64

# %%
datatypeCrime = pd.DataFrame({'Types of Crime': [residencecount,healthcount,worshipcount,pubcount,retialcount,tranportcount,foodbevcount,financecount,othercount]},index=['Residential','Health','Worship','Pub','Retail','Transport','Food & Bev','Finance','Other'])

plot = datatypeCrime.plot.pie(y='Types of Crime',figsize = (8,8))

# %%
# Residence Category
df1['RESIDENCEBooleanValues'] = df1['PREM_TYP_DESC'].str.contains("RESIDENCE", case=False, na=False).astype(int)
cntRes = df1['RESIDENCEBooleanValues'].value_counts()
cntRes
# Out:
# 0    305860
# 1    194140
# Name: RESIDENCEBooleanValues, dtype: int64

# %%
dataResidence = pd.DataFrame({'Number of Residence Based Crimes': [cntRes[0],cntRes[1]]},index=['Non-Residential','Residential'])

plot = dataResidence.plot.pie(y='Number of Residence Based Crimes',figsize = (8,8))

# %%
# Categorizing types of Crime
counts = df1['LAW_CAT_CD'].value_counts()
print(counts)
# Out:
# MISDEMEANOR    278930
# FELONY         156320
# VIOLATION       64750
# Name: LAW_CAT_CD, dtype: int64

# %%
#Plotting Data from a specific column into a piechart

data = pd.DataFrame({'Number of ':[counts[0],counts[1],counts[2]]},index=['MISDEMEANOR','FELONY','VIOLATION'])

plot = data.plot.pie(y='Number of ',figsize = (5,5))

# %%
# Printing number of cases in each Burrow
burr = df1['BORO_NM'].value_counts()
print(burr)
# Out:
# BROOKLYN         150525
# MANHATTAN        116664
# BRONX            108538
# QUEENS           100935
# STATEN ISLAND     23338
# Name: BORO_NM, dtype: int64

# %%
dataBURR = pd.DataFrame({'Number of crimes per Boroughs':[burr[0],burr[1],burr[2],burr[3],burr[4]]},index=['BROOKLYN','MANHATTAN','BRONX','QUEENS','STATEN ISLAND'])

plot = dataBURR.plot.pie(y='Number of crimes per Boroughs',figsize = (8,8))

# %%
sns.histplot(data=df1, x=df1['LAW_CAT_CD'],color='red')

# %%
sns.histplot(data=df1, x=df1['BORO_NM'],color='blue')

# %% [markdown]
# HYPOTHESIS: Segregate Burrows based on type of crime.

# %%
# MISDEMEANOR in different burrows ('BRONX', 'QUEENS', 'MANHATTAN',
#                                     'STATEN ISLAND','BROOKLYN')

dfMIS = df1.loc[df1['LAW_CAT_CD'] == 'MISDEMEANOR']
lengthMis = len(dfMIS)
print(lengthMis)
# # Brooklyn
dfMisBrooklyn = dfMIS.loc[df1['BORO_NM'] =='BROOKLYN']
lengthMisBrook = len(dfMisBrooklyn)
print('Number of Misdemnors in Brooklyn',lengthMisBrook)
# #Bronx
dfMisBronx = dfMIS.loc[df1['BORO_NM'] =='BRONX']
lengthMisBronx = len(dfMisBronx)
print('Number of Misdemnors in Bronx',lengthMisBronx)
# # QUEENS
dfMisQueens = dfMIS.loc[df1['BORO_NM'] =='QUEENS']
lengthMisQueens = len(dfMisQueens)
print('Number of Misdemnors in Queens',lengthMisQueens)
# #MANHATTAN
dfMisMan =dfMIS.loc[df1['BORO_NM'] =='MANHATTAN']
lengthMisMan = len(dfMisMan)
print('Number of Misdemnors in Manhattan',lengthMisMan)
# #STATEN ISLAND
dfMisSI = dfMIS.loc[df1['BORO_NM'] =='STATEN ISLAND']
lengthMisSI = len(dfMisSI)
print('Number of Misdemnors in Staten Island',lengthMisSI)
# Out:
# 278930
# Number of Misdemnors in Brooklyn 79611
# Number of Misdemnors in Bronx 64835
# Number of Misdemnors in Queens 53677
# Number of Misdemnors in Manhattan 67389
# Number of Misdemnors in Staten Island 13418

# %%
#MISDEMEANOR CASES BY BOROUGH
MisdemeanorByBorough = pd.DataFrame({'Number of Misdemeanors per Boroughs':[lengthMisBrook,lengthMisSI,lengthMisQueens,lengthMisMan,lengthMisBronx]},index=['BROOKLYN','STATEN ISLAND','QUEENS','MANHATTAN','BRONX'])

plot = MisdemeanorByBorough.plot.pie(y='Number of Misdemeanors per Boroughs',figsize = (8,8),title='Misdemeanors per Boroughs')

# %%
df1['FELONY'] = pd.Categorical(df1['LAW_CAT_CD'],categories=['FELONY'])
df1['FELONY']
# Out:
# 46300     FELONY
# 571249       NaN
# 585411    FELONY
# 834377       NaN
# 768712       NaN
#            ...
# 993387       NaN
# 326471       NaN
# 601408    FELONY
# 957908       NaN
# 487216    FELONY
# Name: FELONY, Length: 500000, dtype: category
# Categories (1, object): ['FELONY']

# %%
# Felony by Borough
# Brooklyn
dfFelony= df1.loc[df1['LAW_CAT_CD'] == 'FELONY']
dfBrooklynFelony  = dfFelony.loc[df1['BORO_NM'] == 'BROOKLYN']
numberOfFelonyBrooklyn = len(dfBrooklynFelony)
print('Total Number of Felony Cases in Brooklyn are: ',numberOfFelonyBrooklyn)
# Out:
# Total Number of Felony Cases in Brooklyn are:  50549

# %%
dfFelonyQUEENS  = dfFelony.loc[df1['BORO_NM'] == 'QUEENS']
dfFelonyQUEENS
numberOfFelonyQueens = len(dfFelonyQUEENS)
print('Total Number of Felony Cases in Queens are: ',len(dfFelonyQUEENS))
# Out:
# Total Number of Felony Cases in Queens are:  33885

# %%
dfStatenFelony = dfFelony.loc[df1['BORO_NM'] == 'STATEN ISLAND']
dfStatenFelony
numberOfFelonyStaten = len(dfStatenFelony)
print('Total Number of Felony Cases in Staten Island are: ',len(dfStatenFelony))
# Out:
# Total Number of Felony Cases in Staten Island are:  5415

# %%
dfManhattanFelony = dfFelony.loc[df1['BORO_NM'] == 'MANHATTAN']
dfManhattanFelony
numberOfFelonyManhattan = len(dfManhattanFelony)
print('Total Number of Felony Cases in Manhattan are: ',len(dfManhattanFelony))
# dfManhattanFelony.head()
# Out:
# Total Number of Felony Cases in Manhattan are:  36282

# %%
dfBronxFelony = dfFelony.loc[df1['BORO_NM'] == 'BRONX']
dfBronxFelony
numberOfFelonyBronx = len(dfBronxFelony)
print('Total Number of Felony Cases in the Bronx are: ',len(dfBronxFelony))
# Out:
# Total Number of Felony Cases in the Bronx are:  30189

# %%
#MIS


FelonyBurrow = pd.DataFrame({'Number of Felony per Boroughs':[numberOfFelonyBrooklyn,numberOfFelonyStaten,numberOfFelonyQueens,numberOfFelonyManhattan,numberOfFelonyBronx]},index=['BROOKLYN','STATEN ISLAND','QUEENS','MANHATTAN','BRONX'])

plot = FelonyBurrow.plot.pie(y='Number of Felony per Boroughs',figsize = (8,8),title='Felony Per Boroughs')

# %%
# violation by different burrows

df1['Vio'] = pd.Categorical(df1['LAW_CAT_CD'],categories=['VIOLATION'])

lengthVio= len(df1['Vio']) - df1['Vio'].isnull().sum()
print(lengthVio)

# Brooklyn
dfViolation = df1.loc[df1['LAW_CAT_CD'] == 'VIOLATION']
dfBrooklynViolation  = dfViolation.loc[df1['BORO_NM'] == 'BROOKLYN']
numberOfViolationBrooklyn = len(dfBrooklynViolation)
print('Total Number of Violation Cases in Brooklyn are: ',numberOfViolationBrooklyn) 

# Queens
dfQueensViolation  = dfViolation.loc[df1['BORO_NM'] == 'QUEENS']
numberOfQueensViolation = len(dfQueensViolation)
print('Total Number of Violation Cases in Queens are: ',numberOfQueensViolation)

# Bronx
dfBronxViolation  = dfViolation.loc[df1['BORO_NM'] == 'BRONX']
numberOfBronxViolation = len(dfBronxViolation)
print('Total Number of Violation Cases in Bronx are: ',numberOfBronxViolation)

# Staten Island
dfStatenIslandViolation  = dfViolation.loc[df1['BORO_NM'] == 'STATEN ISLAND']
numberOfStatenIslandViolation = len(dfStatenIslandViolation)
print('Total Number of Violation Cases in Staten Island are: ',numberOfStatenIslandViolation)

# Manhattan
dfManhattanViolation  = dfViolation.loc[df1['BORO_NM'] == 'MANHATTAN']
numberOfManhattanViolation = len(dfManhattanViolation)
print('Total Number of Violation Cases in Manhattan are: ',numberOfManhattanViolation)
# Out:
# 64750
# Total Number of Violation Cases in Brooklyn are:  20365
# Total Number of Violation Cases in Queens are:  13373
# Total Number of Violation Cases in Bronx are:  13514
# Total Number of Violation Cases in Staten Island are:  4505
# Total Number of Violation Cases in Manhattan are:  12993

# %%
#Violation graph


ViolationBurrow = pd.DataFrame({'Number of Violations per Boroughs':[numberOfViolationBrooklyn,numberOfQueensViolation,numberOfBronxViolation,numberOfStatenIslandViolation,numberOfManhattanViolation]},index=['BROOKLYN','QUEENS','BRONX','STATEN ISLAND','MANHATTAN'])

plot = ViolationBurrow.plot.pie(y='Number of Violations per Boroughs',figsize = (8,8),title='Violations per Borough')

# %%
dfResidenceVioBrook = dfBrooklynViolation.loc[df1['RESIDENCEBooleanValues'] == 1]
dfResidenceManVio = dfManhattanViolation.loc[df1['RESIDENCEBooleanValues'] == 1]
dfResidenceStatenVio= dfStatenIslandViolation.loc[df1['RESIDENCEBooleanValues'] == 1]
dfResidenceQueensVio = dfQueensViolation.loc[df1['RESIDENCEBooleanValues'] == 1]
dfResidenceBronxVio = dfBronxViolation.loc[df1['RESIDENCEBooleanValues'] == 1]

# %%
v1 = len(dfResidenceVioBrook)
v2 = len(dfResidenceManVio)
v3 = len(dfResidenceStatenVio)
v4 = len(dfResidenceQueensVio)
v5 = len(dfResidenceBronxVio)
FelonyResidenceBurrowPlt = pd.DataFrame({'Number of Residential Violations per burrow':[v1,v2,v3,v4,v5]},index=['BROOKLYN','MANHATTAN','STATEN ISLAND','QUEENS','BRONX'])
plot = FelonyResidenceBurrowPlt.plot.pie(y='Number of Residential Violations per burrow',figsize = (10,10),title='Residential Violations per burrow')

# %%
dfBrooklynFelony
# Out:
#         CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM  \
# 46300    224807992   11/24/2015     16:00:00          NaN          NaN
# 72155    599946215   10/30/2015     15:00:00   10/31/2015     15:30:00
# 399713   267023044    3/11/2015     19:15:00          NaN          NaN
# 556507   626612429   10/28/2014     10:00:00   10/28/2014     10:05:00
# 570457   542577214   10/18/2014     13:15:00   10/18/2014     13:42:00
# ...            ...          ...          ...          ...          ...
# 852180   788133994     4/3/2014      6:45:00          NaN          NaN
# 780460   405215789    5/25/2014     16:25:00    5/25/2014     16:25:00
# 111132   684653125    10/6/2015     19:00:00    10/7/2015      1:30:00
# 692141   993327336    7/26/2014      3:00:00    7/26/2014      3:05:00
# 601408   916467724    9/24/2014     10:00:00    9/27/2014     13:30:00
#
#             RPT_DT  KY_CD                       OFNS_DESC  PD_CD  \
# 46300   11/24/2015    112                     THEFT-FRAUD  739.0
# 72155    11/5/2015    106                  FELONY ASSAULT  109.0
# 399713   3/11/2015    109                   GRAND LARCENY  443.0
# 556507  10/28/2014    105                         ROBBERY  397.0
# 570457  10/18/2014    106                  FELONY ASSAULT  109.0
# ...            ...    ...                             ...    ...
# 852180    4/3/2014    105                         ROBBERY  386.0
# 780460   5/25/2014    106                  FELONY ASSAULT  109.0
# 111132   10/7/2015    110  GRAND LARCENY OF MOTOR VEHICLE  441.0
# 692141   7/26/2014    105                         ROBBERY  386.0
# 601408   9/27/2014    107                        BURGLARY  224.0
#
#                                    PD_DESC  ... HADEVELOPT X_COORD_CD  \
# 46300            FRAUD,UNCLASSIFIED-FELONY  ...        NaN   986889.0
# 72155             ASSAULT 2,1,UNCLASSIFIED  ...        NaN   997175.0
# 399713            LARCENY,GRAND OF BICYCLE  ...        NaN  1005474.0
# 556507      ROBBERY,OPEN AREA UNCLASSIFIED  ...        NaN  1004100.0
# 570457            ASSAULT 2,1,UNCLASSIFIED  ...        NaN   998785.0
# ...                                    ...  ...        ...        ...
# 852180  ROBBERY,PERSONAL ELECTRONIC DEVICE  ...        NaN  1012247.0
# 780460            ASSAULT 2,1,UNCLASSIFIED  ...        NaN   990736.0
# 111132               LARCENY,GRAND OF AUTO  ...        NaN  1000320.0
# 692141  ROBBERY,PERSONAL ELECTRONIC DEVICE  ...        NaN   997365.0
# 601408      BURGLARY,RESIDENCE,UNKNOWN TIM  ...        NaN  1011862.0
#
#        Y_COORD_CD   Latitude  Longitude                        Lat_Lon  \
# 46300    181967.0  40.666142 -73.990489  (40.666141926, -73.990488846)
# 72155    155497.0  40.593478 -73.953462  (40.593478322, -73.953462395)
# 399713   194101.0  40.699422 -73.923459  (40.699421942, -73.923458748)
# 556507   189675.0  40.687277 -73.928427   (40.687276786, -73.92842701)
# 570457   183772.0  40.671085 -73.947604  (40.671084712, -73.947604376)
# ...           ...        ...        ...                            ...
# 852180   185920.0  40.676948 -73.899066  (40.676948151, -73.899066465)
# 780460   160541.0  40.607330 -73.976642  (40.607330132, -73.976642456)
# 111132   183659.0  40.670772 -73.942071  (40.670771899, -73.942071142)
# 692141   189471.0  40.686729 -73.952712  (40.686729395, -73.952712228)
# 601408   169726.0  40.632500 -73.900521    (40.63250039, -73.90052077)
#
#        Food & beverage Food and beverage RESIDENCEBooleanValues  FELONY
# 46300                0                 1                      1  FELONY
# 72155                0                 1                      1  FELONY
# 399713               0                 1                      0  FELONY
# 556507               0                 1                      0  FELONY
# 570457               0                 1                      1  FELONY
# ...                ...               ...                    ...     ...
# 852180               0                 1                      0  FELONY
# 780460               0                 1                      1  FELONY
# 111132               0                 1                      0  FELONY
# 692141               0                 1                      0  FELONY
# 601408               0                 1                      1  FELONY
#
# [50549 rows x 28 columns]

# %%
dfResidenceMIS = dfMisBrooklyn.loc[df1['RESIDENCEBooleanValues'] == 1]
dfResidenceManMIS = dfMisMan.loc[df1['RESIDENCEBooleanValues'] == 1]
dfResidenceStatenMIS= dfMisSI.loc[df1['RESIDENCEBooleanValues'] == 1]
dfResidenceQueensMIS = dfMisQueens.loc[df1['RESIDENCEBooleanValues'] == 1]
dfResidenceBronxMIS = dfMisBronx.loc[df1['RESIDENCEBooleanValues'] == 1]

# %%
misCnt1 = len(dfResidenceMIS)
misCnt2 = len(dfResidenceManMIS)
misCnt3 = len(dfResidenceStatenMIS)
misCnt4 = len(dfResidenceQueensMIS)
misCnt5 = len(dfResidenceBronxMIS)

# %%
MISResidenceBurrowPlt = pd.DataFrame({'Number of Residential Misdemnors per burrow':[misCnt1,misCnt2,misCnt3,misCnt4,misCnt5]},index=['BROOKLYN','MANHATTAN','STATEN ISLAND','QUEENS','BRONX'])
plot = MISResidenceBurrowPlt.plot.pie(y='Number of Residential Misdemnors per burrow',figsize = (10,10),title='Residential  Misdemenors per burrow')

# %%
# # To get type of Crime in Each Burrow
dfResidenceBrooklynFelony = dfBrooklynFelony.loc[df1['RESIDENCEBooleanValues'] == 1]
dfResidenceBrooklynFelony
dfResidenceManFelony = dfManhattanFelony.loc[df1['RESIDENCEBooleanValues'] == 1]
dfResidenceStatenFelony= dfStatenFelony.loc[df1['RESIDENCEBooleanValues'] == 1]
dfResidenceQueensFelony = dfFelonyQUEENS.loc[df1['RESIDENCEBooleanValues'] == 1]
dfResidenceBronxFelony = dfBronxFelony.loc[df1['RESIDENCEBooleanValues'] == 1]

# %%
c1 = len(dfResidenceBrooklynFelony)
c2 = len(dfResidenceManFelony)
c3 = len(dfResidenceStatenFelony)
c4 = len(dfResidenceQueensFelony)
c5 = len(dfResidenceBronxFelony)
FelonyResidenceBurrowPlt = pd.DataFrame({'Number of Residential Felonies per burrow':[c1,c2,c3,c4,c5]},index=['BROOKLYN','MANHATTAN','STATEN ISLAND','QUEENS','BRONX'])
plot = FelonyResidenceBurrowPlt.plot.pie(y='Number of Residential Felonies per burrow',figsize = (10,10),title='Residential Felonies per burrow')

# %%
s=pd.Series(df1['PREM_TYP_DESC'])

# %%
s.map('This is a {}'.format)
# Out:
# 46300     This is a RESIDENCE - APT. HOUSE
# 571249         This is a BUS (NYC TRANSIT)
# 585411       This is a COMMERCIAL BUILDING
# 834377          This is a DEPARTMENT STORE
# 768712    This is a RESIDENCE - APT. HOUSE
#                         ...
# 993387               This is a CHAIN STORE
# 326471    This is a RESIDENCE - APT. HOUSE
# 601408    This is a RESIDENCE - APT. HOUSE
# 957908    This is a RESIDENCE - APT. HOUSE
# 487216    This is a RESIDENCE - APT. HOUSE
# Name: PREM_TYP_DESC, Length: 500000, dtype: object

# %%
b=pd.Series(df1['BORO_NM'])

# %%
b.map('This is: {}'.format)
# Out:
# 46300      This is: BROOKLYN
# 571249     This is: BROOKLYN
# 585411       This is: QUEENS
# 834377    This is: MANHATTAN
# 768712       This is: QUEENS
#                  ...
# 993387    This is: MANHATTAN
# 326471    This is: MANHATTAN
# 601408     This is: BROOKLYN
# 957908    This is: MANHATTAN
# 487216        This is: BRONX
# Name: BORO_NM, Length: 500000, dtype: object
